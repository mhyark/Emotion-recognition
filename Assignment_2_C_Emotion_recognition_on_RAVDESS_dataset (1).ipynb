# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os # interface with underlying OS that python is running on
# CREATE DIRECTORY OF AUDIO FILES 
path = "/content/drive/MyDrive/ravdess/ravdess/"
actor_folders = os.listdir(path) #list files in audio directory
actor_folders.sort() 
actor_folders[0:5]
# Out:
# ['Actor_21', 'Actor_22', 'Actor_23', 'Actor_24', 'Images']

# %%
try:
    # creating a folder named Wave
    if not os.path.exists('/content/drive/MyDrive/ravdess/ravdess/Wave'): 
        os.makedirs('/content/drive/MyDrive/ravdess/ravdess/Wave') 
  
# if not created then raise error 
except OSError: 
    print ('Error: Creating directory of Wave')

# %% [markdown]
# # Process Audio Files

# %% [markdown]
# ## Extract Audio From Video

# %%
import os
from glob import glob
from tqdm import tqdm

try:
    # creating a folder named Wave
    if not os.path.exists('/content/drive/MyDrive/ravdess/ravdess/Wave'): 
        os.makedirs('/content/drive/MyDrive/ravdess/ravdess/Wave') 
  
# if not created then raise error 
except OSError: 
    print ('Error: Creating directory of Wave')

inputdir = '/content/drive/MyDrive/ravdess/ravdess/Actor_*' 
outputdir = '/content/drive/MyDrive/ravdess/ravdess/Wave'
#iterate over Actor folders
for i in actor_folders:
      print(i)
      # go through files in Actor folder
      for filename in os.listdir('/content/drive/MyDrive/ravdess/ravdess/' + i):
           actual_filename = filename[:-4]
           os.system('ffmpeg -i {}/{} -acodec pcm_s16le -ar 16000 {}/{}.wav'.format(inputdir, filename, outputdir, actual_filename))
# Out:
# Actor_21
# Actor_22
# Actor_23
# Actor_24
# Images
# Wave

# %%
import shutil, sys 
shutil.rmtree('/content/drive/MyDrive/ravdess/ravdess/Wave')

# %%
pip install tqdm
# Out:
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (4.41.1)

# %% [markdown]
# ## Extract Features And Do Some Process Operations

# %%
def extract_feature(file_name):
    """Function Extracts Features from WAV file"""
    X, sample_rate = librosa.load(file_name)
    stft=np.abs(librosa.stft(X))
    result=np.array([])
    mfccs=np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T,axis=0)
    result=np.hstack((result, mfccs))
    chroma=np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T,axis=0)
    result=np.hstack((result, chroma))
    mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
    result=np.hstack((result, mel))
    return result

# %%
emotions={
  '01':'neutral/calm',
  '02':'happy',
  '03':'sad',
  '04':'angry',
  '05':'fearful',
  '06':'disgust',
  '07':'surprised'
}

def gender(g):
    """Returns Gender Label"""
    if int(g[0:2]) % 2 == 0:
        return 'female'
    else:
        return 'male'

# %%
from tqdm import tqdm
import glob 
import pandas as pd
import numpy as np
import librosa
import librosa.display
  
x,y=[],[]
for file in tqdm(glob.glob("/content/drive/MyDrive/ravdess/ravdess/Wave/*.wav")):
        file_name=os.path.basename(file)
        emotion=emotions[file_name.split("-")[3]] + '_' + gender(file_name.split("-")[-1])
        feature=extract_feature(file)
        mean = np.mean(feature, axis=0)
        std = np.std(feature, axis=0)
        feature =(feature - mean)/std

        x.append(feature)
        y.append(emotion)
# Out:
#  13%|█▎        | 60/453 [00:15<01:32,  4.25it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  13%|█▎        | 61/453 [00:15<01:33,  4.21it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  14%|█▎        | 62/453 [00:16<01:33,  4.16it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  14%|█▍        | 63/453 [00:16<01:33,  4.19it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  14%|█▍        | 64/453 [00:16<01:37,  4.01it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  14%|█▍        | 65/453 [00:16<01:36,  4.02it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  15%|█▍        | 66/453 [00:17<01:35,  4.04it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  15%|█▍        | 67/453 [00:17<01:34,  4.08it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  15%|█▌        | 68/453 [00:17<01:34,  4.07it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  15%|█▌        | 69/453 [00:17<01:34,  4.07it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  15%|█▌        | 70/453 [00:18<01:37,  3.94it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  16%|█▌        | 71/453 [00:18<01:35,  4.01it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  16%|█▌        | 72/453 [00:18<01:35,  3.99it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  16%|█▌        | 73/453 [00:18<01:34,  4.02it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  16%|█▋        | 74/453 [00:18<01:33,  4.04it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  17%|█▋        | 75/453 [00:19<01:33,  4.06it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  17%|█▋        | 76/453 [00:19<01:32,  4.09it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  17%|█▋        | 77/453 [00:19<01:32,  4.08it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  17%|█▋        | 78/453 [00:19<01:32,  4.06it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  17%|█▋        | 79/453 [00:20<01:31,  4.08it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  18%|█▊        | 80/453 [00:20<01:30,  4.10it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  18%|█▊        | 81/453 [00:20<01:32,  4.04it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  18%|█▊        | 82/453 [00:20<01:31,  4.04it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  18%|█▊        | 83/453 [00:21<01:35,  3.87it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  19%|█▊        | 84/453 [00:21<01:35,  3.87it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  19%|█▉        | 85/453 [00:21<01:34,  3.90it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  19%|█▉        | 86/453 [00:22<01:33,  3.92it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  19%|█▉        | 87/453 [00:22<01:33,  3.90it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  19%|█▉        | 88/453 [00:22<01:33,  3.91it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  20%|█▉        | 89/453 [00:22<01:32,  3.95it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  20%|█▉        | 90/453 [00:23<01:31,  3.97it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  20%|██        | 91/453 [00:23<01:30,  3.98it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  20%|██        | 92/453 [00:23<01:31,  3.94it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  34%|███▎      | 152/453 [00:38<01:13,  4.10it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  34%|███▍      | 154/453 [00:38<01:11,  4.16it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  34%|███▍      | 155/453 [00:39<01:10,  4.24it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  34%|███▍      | 156/453 [00:39<01:10,  4.24it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  35%|███▍      | 157/453 [00:39<01:09,  4.26it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  35%|███▍      | 158/453 [00:39<01:09,  4.23it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  35%|███▌      | 159/453 [00:40<01:09,  4.24it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  35%|███▌      | 160/453 [00:40<01:09,  4.21it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  36%|███▌      | 161/453 [00:40<01:08,  4.26it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  36%|███▌      | 162/453 [00:40<01:08,  4.23it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  36%|███▌      | 163/453 [00:41<01:07,  4.27it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  36%|███▌      | 164/453 [00:41<01:07,  4.31it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  36%|███▋      | 165/453 [00:41<01:08,  4.23it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  37%|███▋      | 166/453 [00:41<01:07,  4.23it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  37%|███▋      | 167/453 [00:41<01:09,  4.12it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  37%|███▋      | 168/453 [00:42<01:08,  4.14it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  37%|███▋      | 169/453 [00:42<01:09,  4.10it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  38%|███▊      | 170/453 [00:42<01:09,  4.07it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  38%|███▊      | 171/453 [00:42<01:08,  4.15it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  38%|███▊      | 172/453 [00:43<01:07,  4.17it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  38%|███▊      | 173/453 [00:43<01:06,  4.19it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  38%|███▊      | 174/453 [00:43<01:06,  4.18it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  39%|███▊      | 175/453 [00:43<01:07,  4.10it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  39%|███▉      | 176/453 [00:44<01:06,  4.14it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  39%|███▉      | 177/453 [00:44<01:06,  4.14it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  39%|███▉      | 178/453 [00:44<01:05,  4.17it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  40%|███▉      | 179/453 [00:44<01:05,  4.18it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  40%|███▉      | 180/453 [00:45<01:04,  4.20it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  40%|███▉      | 181/453 [00:45<01:04,  4.19it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  40%|████      | 182/453 [00:45<01:05,  4.14it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  40%|████      | 183/453 [00:45<01:04,  4.17it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  41%|████      | 184/453 [00:46<01:05,  4.12it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  41%|████      | 185/453 [00:46<01:05,  4.10it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  41%|████      | 186/453 [00:46<01:05,  4.11it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  41%|████▏     | 187/453 [00:46<01:05,  4.05it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  42%|████▏     | 188/453 [00:47<01:04,  4.12it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  42%|████▏     | 189/453 [00:47<01:04,  4.12it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  42%|████▏     | 190/453 [00:47<01:05,  4.02it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  42%|████▏     | 191/453 [00:47<01:03,  4.12it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  42%|████▏     | 192/453 [00:48<01:02,  4.16it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  43%|████▎     | 193/453 [00:48<01:02,  4.19it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  43%|████▎     | 194/453 [00:48<01:01,  4.21it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  43%|████▎     | 195/453 [00:48<01:00,  4.25it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  43%|████▎     | 196/453 [00:48<01:00,  4.22it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  43%|████▎     | 197/453 [00:49<01:01,  4.17it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  44%|████▎     | 198/453 [00:49<01:02,  4.07it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  44%|████▍     | 199/453 [00:49<01:02,  4.07it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  44%|████▍     | 200/453 [00:49<01:01,  4.09it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  44%|████▍     | 201/453 [00:50<01:00,  4.13it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  45%|████▍     | 202/453 [00:50<01:02,  4.04it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  45%|████▍     | 203/453 [00:50<01:02,  4.01it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  45%|████▌     | 204/453 [00:50<01:02,  4.01it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  45%|████▌     | 205/453 [00:51<01:00,  4.07it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  45%|████▌     | 206/453 [00:51<01:01,  4.04it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  46%|████▌     | 207/453 [00:51<01:00,  4.05it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  46%|████▌     | 208/453 [00:51<00:59,  4.09it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  46%|████▌     | 209/453 [00:52<00:59,  4.07it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  46%|████▋     | 210/453 [00:52<00:59,  4.10it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  47%|████▋     | 211/453 [00:52<01:00,  4.02it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  47%|████▋     | 212/453 [00:52<00:59,  4.04it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  60%|█████▉    | 271/453 [01:07<00:42,  4.26it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  60%|██████    | 274/453 [01:07<00:41,  4.28it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  61%|██████    | 275/453 [01:08<00:42,  4.22it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  61%|██████    | 276/453 [01:08<00:42,  4.17it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  61%|██████    | 277/453 [01:08<00:42,  4.17it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  61%|██████▏   | 278/453 [01:08<00:42,  4.10it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  62%|██████▏   | 279/453 [01:09<00:42,  4.08it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  62%|██████▏   | 280/453 [01:09<00:42,  4.06it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  62%|██████▏   | 281/453 [01:09<00:44,  3.90it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  62%|██████▏   | 282/453 [01:09<00:43,  3.93it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  62%|██████▏   | 283/453 [01:10<00:43,  3.87it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  63%|██████▎   | 284/453 [01:10<00:42,  3.94it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  63%|██████▎   | 285/453 [01:10<00:41,  4.09it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  63%|██████▎   | 286/453 [01:10<00:42,  3.96it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  63%|██████▎   | 287/453 [01:11<00:41,  4.04it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  64%|██████▎   | 288/453 [01:11<00:39,  4.15it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  64%|██████▍   | 289/453 [01:11<00:38,  4.21it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  64%|██████▍   | 290/453 [01:11<00:38,  4.22it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  64%|██████▍   | 291/453 [01:12<00:37,  4.30it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  64%|██████▍   | 292/453 [01:12<00:36,  4.38it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  65%|██████▍   | 293/453 [01:12<00:37,  4.31it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  65%|██████▍   | 294/453 [01:12<00:37,  4.28it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  65%|██████▌   | 295/453 [01:12<00:37,  4.21it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  65%|██████▌   | 296/453 [01:13<00:36,  4.24it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  66%|██████▌   | 297/453 [01:13<00:37,  4.16it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  66%|██████▌   | 298/453 [01:13<00:38,  4.06it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  66%|██████▌   | 299/453 [01:13<00:38,  4.02it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  66%|██████▌   | 300/453 [01:14<00:37,  4.12it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  66%|██████▋   | 301/453 [01:14<00:38,  3.96it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  67%|██████▋   | 302/453 [01:14<00:37,  4.00it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  67%|██████▋   | 303/453 [01:14<00:36,  4.10it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  67%|██████▋   | 304/453 [01:15<00:35,  4.18it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  67%|██████▋   | 305/453 [01:15<00:35,  4.20it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  68%|██████▊   | 306/453 [01:15<00:34,  4.29it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  68%|██████▊   | 307/453 [01:15<00:33,  4.30it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  68%|██████▊   | 308/453 [01:16<00:33,  4.34it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  68%|██████▊   | 309/453 [01:16<00:32,  4.37it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  68%|██████▊   | 310/453 [01:16<00:32,  4.41it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  69%|██████▊   | 311/453 [01:16<00:32,  4.34it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  69%|██████▉   | 312/453 [01:16<00:32,  4.34it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  69%|██████▉   | 313/453 [01:17<00:32,  4.33it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  69%|██████▉   | 314/453 [01:17<00:31,  4.35it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  70%|██████▉   | 315/453 [01:17<00:32,  4.30it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  70%|██████▉   | 316/453 [01:17<00:32,  4.25it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  70%|██████▉   | 317/453 [01:18<00:32,  4.19it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  70%|███████   | 318/453 [01:18<00:31,  4.24it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  70%|███████   | 319/453 [01:18<00:31,  4.28it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  71%|███████   | 320/453 [01:18<00:31,  4.25it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  71%|███████   | 321/453 [01:19<00:31,  4.21it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  71%|███████   | 322/453 [01:19<00:30,  4.30it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  71%|███████▏  | 323/453 [01:19<00:30,  4.22it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  72%|███████▏  | 324/453 [01:19<00:31,  4.11it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  72%|███████▏  | 325/453 [01:20<00:30,  4.13it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  72%|███████▏  | 326/453 [01:20<00:30,  4.21it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  72%|███████▏  | 327/453 [01:20<00:29,  4.30it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  72%|███████▏  | 328/453 [01:20<00:29,  4.30it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  73%|███████▎  | 329/453 [01:20<00:28,  4.36it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  73%|███████▎  | 330/453 [01:21<00:28,  4.34it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  73%|███████▎  | 331/453 [01:21<00:28,  4.33it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  73%|███████▎  | 332/453 [01:21<00:28,  4.28it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  87%|████████▋ | 393/453 [01:37<00:15,  3.97it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  87%|████████▋ | 394/453 [01:37<00:14,  4.01it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  87%|████████▋ | 395/453 [01:38<00:14,  4.03it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  87%|████████▋ | 396/453 [01:38<00:13,  4.08it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  88%|████████▊ | 397/453 [01:38<00:13,  4.14it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  88%|████████▊ | 398/453 [01:38<00:13,  4.10it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  88%|████████▊ | 399/453 [01:38<00:13,  4.09it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  88%|████████▊ | 400/453 [01:39<00:13,  4.08it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  89%|████████▊ | 401/453 [01:39<00:12,  4.09it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  89%|████████▊ | 402/453 [01:39<00:12,  4.03it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  89%|████████▉ | 403/453 [01:40<00:12,  3.99it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  89%|████████▉ | 404/453 [01:40<00:12,  3.93it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  89%|████████▉ | 405/453 [01:40<00:12,  3.97it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  90%|████████▉ | 406/453 [01:40<00:11,  3.93it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  90%|████████▉ | 407/453 [01:41<00:11,  3.90it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  90%|█████████ | 408/453 [01:41<00:11,  3.93it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  90%|█████████ | 409/453 [01:41<00:10,  4.01it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  91%|█████████ | 410/453 [01:41<00:10,  3.95it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  91%|█████████ | 411/453 [01:42<00:10,  4.01it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  91%|█████████ | 412/453 [01:42<00:10,  4.00it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  91%|█████████ | 413/453 [01:42<00:10,  3.95it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  91%|█████████▏| 414/453 [01:42<00:09,  3.98it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  92%|█████████▏| 415/453 [01:43<00:09,  3.96it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  92%|█████████▏| 416/453 [01:43<00:09,  3.88it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  92%|█████████▏| 417/453 [01:43<00:09,  3.92it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  92%|█████████▏| 418/453 [01:43<00:08,  3.90it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  92%|█████████▏| 419/453 [01:44<00:08,  3.80it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  93%|█████████▎| 420/453 [01:44<00:08,  3.77it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  93%|█████████▎| 421/453 [01:44<00:08,  3.72it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  93%|█████████▎| 422/453 [01:44<00:08,  3.82it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  93%|█████████▎| 423/453 [01:45<00:07,  3.95it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  94%|█████████▎| 424/453 [01:45<00:07,  3.93it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  94%|█████████▍| 425/453 [01:45<00:07,  3.87it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  94%|█████████▍| 426/453 [01:45<00:07,  3.80it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  94%|█████████▍| 427/453 [01:46<00:06,  3.80it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  94%|█████████▍| 428/453 [01:46<00:06,  3.77it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  95%|█████████▍| 429/453 [01:46<00:06,  3.85it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  95%|█████████▍| 430/453 [01:46<00:06,  3.69it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  95%|█████████▌| 431/453 [01:47<00:05,  3.75it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  95%|█████████▌| 432/453 [01:47<00:05,  3.76it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  96%|█████████▌| 433/453 [01:47<00:05,  3.82it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  96%|█████████▌| 434/453 [01:48<00:04,  3.83it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  96%|█████████▌| 435/453 [01:48<00:04,  3.81it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  96%|█████████▌| 436/453 [01:48<00:04,  3.79it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  96%|█████████▋| 437/453 [01:48<00:04,  3.87it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  97%|█████████▋| 438/453 [01:49<00:03,  3.93it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  97%|█████████▋| 439/453 [01:49<00:03,  3.85it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  97%|█████████▋| 440/453 [01:49<00:03,  3.81it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  97%|█████████▋| 441/453 [01:49<00:03,  3.75it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  98%|█████████▊| 442/453 [01:50<00:02,  3.79it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  98%|█████████▊| 443/453 [01:50<00:02,  3.74it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  98%|█████████▊| 444/453 [01:50<00:02,  3.75it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  98%|█████████▊| 445/453 [01:50<00:02,  3.88it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  98%|█████████▊| 446/453 [01:51<00:01,  3.81it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  99%|█████████▊| 447/453 [01:51<00:01,  3.83it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  99%|█████████▉| 448/453 [01:51<00:01,  3.89it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  99%|█████████▉| 449/453 [01:51<00:01,  3.95it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
#  99%|█████████▉| 450/453 [01:52<00:00,  4.00it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
# 100%|█████████▉| 451/453 [01:52<00:00,  3.99it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
# 100%|█████████▉| 452/453 [01:52<00:00,  3.84it/s]/usr/local/lib/python3.6/dist-packages/librosa/core/pitch.py:145: UserWarning: Trying to estimate tuning from empty frequency set.
#   warnings.warn('Trying to estimate tuning from empty frequency set.')
# 100%|██████████| 453/453 [01:52<00:00,  4.01it/s]

# %%
print(x)
print(y)
# Out:
# [array([-1.32529826e+01,  1.80034398e+00,  7.95289647e-02,  5.94898909e-01,
#         1.19141786e-01,  1.10474789e-01,  7.09013729e-02,  1.49062920e-02,
#        -1.36793007e-01,  8.61843924e-02,  9.86503041e-02, -1.84123744e-02,
#         1.10268349e-01,  8.38261475e-02,  8.77421762e-02,  1.39689045e-02,
#         6.23162500e-02,  4.87875366e-02,  9.63537574e-02,  3.70109374e-02,
#         1.45853442e-02,  7.00071068e-02, -2.02334578e-04,  1.06274154e-02,
#         1.25003479e-02,  3.91032035e-02,  4.20328874e-03,  3.97497293e-02,
#         6.44163309e-02,  7.56374773e-02,  5.82302460e-02,  2.13742782e-02,
#         3.72111005e-02,  2.67856606e-02,  5.19930279e-02,  3.19869956e-02,
#         2.45804313e-02,  2.40483524e-03,  1.80888676e-02,  2.83622045e-02,
#         7.79588193e-02,  7.84959187e-02,  7.93505097e-02,  7.92122868e-02,
#         7.95605343e-02,  8.03745865e-02,  8.01339573e-02,  8.15845960e-02,
#         8.14274364e-02,  8.04246936e-02,  7.98900319e-02,  7.88342884e-02,
#         6.43882247e-02,  6.44010262e-02,  6.52814951e-02,  6.60901104e-02,
#         6.48737309e-02,  6.46890480e-02,  6.55271316e-02,  6.63289505e-02,
#         6.65164420e-02,  6.49884665e-02,  6.52008582e-02,  6.60424614e-02,
#         6.54985017e-02,  6.53701952e-02,  6.72486575e-02,  6.78790566e-02,
#         6.63575442e-02,  6.73151860e-02,  6.58175232e-02,  6.52020292e-02,
#         6.49780030e-02,  6.61689127e-02,  6.55706518e-02,  6.56430004e-02,
#         6.69577445e-02,  7.69527243e-02,  6.96694495e-02,  6.53105719e-02,
#         6.48707887e-02,  6.62236172e-02,  6.53916367e-02,  6.44266334e-02,
#         6.45979383e-02,  6.46036102e-02,  6.44184756e-02,  6.44433233e-02,
#         6.47970689e-02,  6.45432395e-02,  6.44335520e-02,  6.46330219e-02,
#         6.47021834e-02,  6.44332811e-02,  6.48678307e-02,  6.64586155e-02,
#         6.46841948e-02,  6.45282486e-02,  6.45661306e-02,  6.44607805e-02,
#         6.44461962e-02,  6.44235448e-02,  6.44374121e-02,  6.44276080e-02,
#         6.44328915e-02,  6.44671687e-02,  6.44223872e-02,  6.44063185e-02,
#         6.44130442e-02,  6.44079467e-02,  6.43979260e-02,  6.44016333e-02,
#         6.43934866e-02,  6.44003117e-02,  6.43964547e-02,  6.43955796e-02,
#         6.43901216e-02,  6.43884806e-02,  6.43892075e-02,  6.43889425e-02,
#         6.43886088e-02,  6.43892790e-02,  6.43932257e-02,  6.43969916e-02,
#         6.43969110e-02,  6.44039120e-02,  6.43974706e-02,  6.43947112e-02,
#         6.43928646e-02,  6.43931192e-02,  6.43931925e-02,  6.43935690e-02,
#         6.43948438e-02,  6.43941033e-02,  6.43951995e-02,  6.43974797e-02,
#         6.43939812e-02,  6.43927411e-02,  6.43925464e-02,  6.43935824e-02,
#         6.43892424e-02,  6.43878431e-02,  6.43880948e-02,  6.43893750e-02,
#         6.43907262e-02,  6.43914953e-02,  6.43900688e-02,  6.43911335e-02,
#         6.43893359e-02,  6.43901521e-02,  6.43902871e-02,  6.43912385e-02,
#         6.43894086e-02,  6.43882385e-02,  6.43877379e-02,  6.43878360e-02,
#         6.43878484e-02,  6.43879494e-02,  6.43880370e-02,  6.43874676e-02,
#         6.43878651e-02,  6.43874147e-02,  6.43875597e-02,  6.43874020e-02,
#         6.43873774e-02,  6.43871189e-02,  6.43869192e-02,  6.43867679e-02,
#         6.43867620e-02,  6.43867619e-02,  6.43867619e-02,  6.43867619e-02,
#         6.43867619e-02,  6.43867619e-02,  6.43867619e-02,  6.43867619e-02,
#         6.43867619e-02,  6.43867619e-02,  6.43867619e-02,  6.43867619e-02]), array([-1.32572465e+01,  1.76422323e+00, -6.47064465e-02,  5.56741147e-01,
#         9.58231586e-02,  7.54235167e-02,  3.93583776e-02,  4.77692574e-02,
#        -1.64233275e-01,  7.23945029e-02,  7.05409466e-02, -5.32507941e-02,
#         9.77261717e-02,  5.75258630e-02,  7.36859346e-02, -2.64026295e-02,
#         4.88253301e-02,  2.14931231e-02,  7.65743494e-02,  3.35592701e-02,
#         7.06231496e-03,  7.04019184e-02, -2.74032283e-02, -9.33192807e-03,
#         7.08182890e-03,  2.76499091e-02, -1.58015261e-02,  4.25804546e-02,
#         4.46417117e-02,  4.20978307e-02,  5.70124785e-02,  1.32073837e-02,
#         3.74063609e-02,  2.68589722e-02,  5.37852205e-02,  4.05614185e-02,
#         1.88792548e-02,  1.82627083e-02,  3.38425541e-02,  1.96206800e-02,
#         8.31833243e-02,  8.31056653e-02,  8.36839375e-02,  8.37546155e-02,
#         8.42340569e-02,  8.55102406e-02,  8.50210696e-02,  8.66837646e-02,
#         8.64277454e-02,  8.59098535e-02,  8.42897607e-02,  8.36128769e-02,
#         6.91061384e-02,  6.91212811e-02,  6.98307770e-02,  7.05777887e-02,
#         6.98785126e-02,  6.96425630e-02,  7.02848591e-02,  7.17800997e-02,
#         7.09117681e-02,  6.99469197e-02,  6.96841255e-02,  7.11054377e-02,
#         7.10465895e-02,  7.10134055e-02,  7.16057901e-02,  7.31703607e-02,
#         7.23265244e-02,  6.97671423e-02,  7.06103649e-02,  7.05794769e-02,
#         6.96715570e-02,  6.95668320e-02,  7.14590091e-02,  7.09728422e-02,
#         7.00942736e-02,  7.28902908e-02,  8.20863427e-02,  7.14126432e-02,
#         6.94521016e-02,  7.05698898e-02,  6.97351431e-02,  6.91516355e-02,
#         6.92206709e-02,  6.93945560e-02,  6.94837076e-02,  6.91789828e-02,
#         6.92068229e-02,  6.94407695e-02,  6.95984250e-02,  6.93130156e-02,
#         6.91974037e-02,  6.98720974e-02,  6.97235467e-02,  6.94090609e-02,
#         6.95267429e-02,  6.94813915e-02,  6.91971465e-02,  6.92568201e-02,
#         6.93368007e-02,  6.91544759e-02,  6.93285384e-02,  6.92020459e-02,
#         6.92371761e-02,  6.92763566e-02,  6.91523322e-02,  6.94097486e-02,
#         6.92008808e-02,  6.91567203e-02,  6.91314999e-02,  6.91399731e-02,
#         6.91373638e-02,  6.91645742e-02,  6.91305876e-02,  6.91249468e-02,
#         6.91131419e-02,  6.91120802e-02,  6.91116085e-02,  6.91141525e-02,
#         6.91124641e-02,  6.91137048e-02,  6.91322299e-02,  6.91469043e-02,
#         6.91248675e-02,  6.91480883e-02,  6.91533176e-02,  6.91654998e-02,
#         6.91380063e-02,  6.91305623e-02,  6.91349566e-02,  6.91310407e-02,
#         6.91506181e-02,  6.91710014e-02,  6.91649952e-02,  6.91505589e-02,
#         6.91258903e-02,  6.91233299e-02,  6.91229174e-02,  6.91132755e-02,
#         6.91079383e-02,  6.91071740e-02,  6.91070562e-02,  6.91084775e-02,
#         6.91097851e-02,  6.91092483e-02,  6.91152087e-02,  6.91129862e-02,
#         6.91109747e-02,  6.91115724e-02,  6.91103148e-02,  6.91086489e-02,
#         6.91074750e-02,  6.91077578e-02,  6.91079178e-02,  6.91073544e-02,
#         6.91069879e-02,  6.91076084e-02,  6.91070132e-02,  6.91068943e-02,
#         6.91070509e-02,  6.91071531e-02,  6.91064680e-02,  6.91062846e-02,
#         6.91064371e-02,  6.91062678e-02,  6.91058973e-02,  6.91058081e-02,
#         6.91058005e-02,  6.91058005e-02,  6.91058005e-02,  6.91058005e-02,
#         6.91058005e-02,  6.91058005e-02,  6.91058005e-02,  6.91058005e-02,
#         6.91058005e-02,  6.91058005e-02,  6.91058005e-02,  6.91058005e-02]), array([-1.32334671e+01,  1.92413700e+00,  2.75999239e-02,  6.33297441e-01,
#         1.18572236e-01,  2.01178255e-01, -1.26095776e-02,  3.38091730e-02,
#        -9.76762579e-02,  9.55240561e-02,  1.29242566e-01,  2.22005732e-03,
#         1.26820516e-01,  8.34213005e-02,  1.08300938e-01, -2.87385200e-02,
#         5.99193093e-02,  3.49830803e-02,  7.05792178e-02,  1.05089753e-02,
#        -9.11690420e-03,  8.57903697e-02, -3.20021400e-02,  1.83997046e-05,
#         1.78337005e-02,  4.10122499e-02,  1.18781909e-02,  3.97494711e-02,
#         4.87490019e-02,  6.72709714e-02,  4.89479588e-02, -3.38237863e-03,
#         3.87134361e-02,  8.03760189e-03,  3.66824936e-02,  3.34060698e-02,
#         2.17747242e-02,  1.41472440e-02,  9.89453597e-03,  2.78385966e-02,
#         7.61901635e-02,  7.75464768e-02,  7.71529773e-02,  7.82741823e-02,
#         7.87870455e-02,  7.97443073e-02,  7.98176213e-02,  7.93346240e-02,
#         7.92020406e-02,  8.02247790e-02,  7.94149213e-02,  7.65448592e-02,
#         6.43644124e-02,  6.43832456e-02,  6.60303027e-02,  6.66351007e-02,
#         6.47081928e-02,  6.46193796e-02,  6.53237335e-02,  6.52892389e-02,
#         6.63807541e-02,  6.48632048e-02,  6.47100793e-02,  6.48977026e-02,
#         6.55295907e-02,  6.49212066e-02,  6.45528120e-02,  6.46123955e-02,
#         6.51807257e-02,  6.53250496e-02,  6.45250829e-02,  6.44603674e-02,
#         6.49500568e-02,  6.46300977e-02,  6.44719488e-02,  6.65924909e-02,
#         6.72483041e-02,  6.45978013e-02,  6.46971756e-02,  6.61115501e-02,
#         6.47169565e-02,  6.44038629e-02,  6.44307124e-02,  6.44352913e-02,
#         6.43736409e-02,  6.43744548e-02,  6.44071777e-02,  6.43776138e-02,
#         6.43727732e-02,  6.44132749e-02,  6.44516924e-02,  6.43807883e-02,
#         6.43934760e-02,  6.45444767e-02,  6.44441560e-02,  6.44290720e-02,
#         6.47328447e-02,  6.44912340e-02,  6.43900202e-02,  6.44140525e-02,
#         6.43705945e-02,  6.43773959e-02,  6.43758429e-02,  6.43721408e-02,
#         6.43751066e-02,  6.43718496e-02,  6.43696328e-02,  6.43782408e-02,
#         6.43843683e-02,  6.43664370e-02,  6.43681282e-02,  6.43694859e-02,
#         6.43662183e-02,  6.43676592e-02,  6.43660211e-02,  6.43685743e-02,
#         6.43656363e-02,  6.43649104e-02,  6.43646067e-02,  6.43644754e-02,
#         6.43644317e-02,  6.43646548e-02,  6.43659780e-02,  6.43660398e-02,
#         6.43653514e-02,  6.43681111e-02,  6.43685783e-02,  6.43675063e-02,
#         6.43660834e-02,  6.43662130e-02,  6.43664677e-02,  6.43665468e-02,
#         6.43660046e-02,  6.43656641e-02,  6.43654666e-02,  6.43656422e-02,
#         6.43652368e-02,  6.43648290e-02,  6.43654668e-02,  6.43663725e-02,
#         6.43652479e-02,  6.43642055e-02,  6.43641278e-02,  6.43640770e-02,
#         6.43642282e-02,  6.43647731e-02,  6.43646627e-02,  6.43652397e-02,
#         6.43686115e-02,  6.43680262e-02,  6.43663089e-02,  6.43654417e-02,
#         6.43645988e-02,  6.43655193e-02,  6.43650910e-02,  6.43645977e-02,
#         6.43645215e-02,  6.43650828e-02,  6.43646804e-02,  6.43645793e-02,
#         6.43646691e-02,  6.43642872e-02,  6.43642489e-02,  6.43641545e-02,
#         6.43640425e-02,  6.43641810e-02,  6.43638970e-02,  6.43637823e-02,
#         6.43637807e-02,  6.43637807e-02,  6.43637807e-02,  6.43637807e-02,
#         6.43637807e-02,  6.43637807e-02,  6.43637807e-02,  6.43637807e-02,
#         6.43637807e-02,  6.43637807e-02,  6.43637807e-02,  6.43637807e-02]), array([-1.32434350e+01,  1.84340511e+00, -1.10246838e-01,  5.98227206e-01,
#         4.64918893e-02,  1.79113021e-01, -1.11169394e-02,  6.21837069e-03,
#        -1.97901636e-01,  5.99475340e-02,  9.39437944e-02, -4.31108509e-02,
#         5.86982076e-02,  3.80951006e-02,  1.09170301e-01, -1.24290637e-02,
#         1.13544398e-01,  4.01352820e-02,  8.08005495e-02,  1.45008161e-02,
#        -1.35188078e-02,  7.52827618e-02, -1.93333019e-02, -1.22880096e-02,
#         2.57402567e-03,  6.75485284e-02, -9.86189838e-03,  4.27091311e-02,
#         5.59341506e-02,  6.64925843e-02,  5.57165723e-02,  1.06042972e-02,
#         5.01757889e-02,  3.56422193e-02,  7.90103011e-02,  3.72123645e-02,
#         1.72755647e-02,  7.89826865e-03,  1.55451504e-02,  2.39751508e-02,
#         8.04078906e-02,  8.15231217e-02,  8.19532671e-02,  8.16739398e-02,
#         8.21460375e-02,  8.30942777e-02,  8.42632803e-02,  8.45984148e-02,
#         8.33732612e-02,  8.27282639e-02,  8.23892735e-02,  8.05319090e-02,
#         6.78671153e-02,  6.78816294e-02,  6.93052515e-02,  7.01679645e-02,
#         6.82046608e-02,  6.82004985e-02,  6.97672172e-02,  6.99665067e-02,
#         7.02142913e-02,  6.86736242e-02,  6.93484653e-02,  6.89753829e-02,
#         6.91868619e-02,  7.07467876e-02,  7.48409543e-02,  7.34735788e-02,
#         7.01284727e-02,  7.12166810e-02,  7.11391383e-02,  7.09246711e-02,
#         6.96156080e-02,  6.93875204e-02,  7.01318977e-02,  7.01977497e-02,
#         6.95294389e-02,  7.13851691e-02,  7.15111488e-02,  6.99976299e-02,
#         6.81710668e-02,  6.86973335e-02,  6.87303220e-02,  6.80084368e-02,
#         6.79278536e-02,  6.80126840e-02,  6.80122637e-02,  6.79567583e-02,
#         6.81000081e-02,  6.81952586e-02,  6.80974649e-02,  6.81202821e-02,
#         6.80175373e-02,  6.80927430e-02,  6.83781294e-02,  6.88818946e-02,
#         6.88454187e-02,  6.81982691e-02,  6.81901089e-02,  6.80259969e-02,
#         6.79704411e-02,  6.80083399e-02,  6.79911439e-02,  6.81392827e-02,
#         6.79526203e-02,  6.79450100e-02,  6.83333801e-02,  6.79288901e-02,
#         6.78985563e-02,  6.78985687e-02,  6.78965832e-02,  6.79243545e-02,
#         6.79115135e-02,  6.79224604e-02,  6.79084369e-02,  6.78732069e-02,
#         6.78719555e-02,  6.78688666e-02,  6.78697689e-02,  6.78703888e-02,
#         6.78700808e-02,  6.78723801e-02,  6.78846354e-02,  6.78908641e-02,
#         6.79009502e-02,  6.79256483e-02,  6.78981654e-02,  6.78846301e-02,
#         6.78821170e-02,  6.78871802e-02,  6.78937241e-02,  6.79024656e-02,
#         6.78991772e-02,  6.78975999e-02,  6.78906300e-02,  6.78968796e-02,
#         6.78870501e-02,  6.78770998e-02,  6.78744687e-02,  6.78758673e-02,
#         6.78751728e-02,  6.78703533e-02,  6.78744613e-02,  6.78741869e-02,
#         6.78747710e-02,  6.78746490e-02,  6.78928458e-02,  6.79534355e-02,
#         6.80524452e-02,  6.79706054e-02,  6.78893648e-02,  6.78884099e-02,
#         6.78845912e-02,  6.78772462e-02,  6.78776443e-02,  6.78782159e-02,
#         6.78772944e-02,  6.78743895e-02,  6.78740626e-02,  6.78735052e-02,
#         6.78685213e-02,  6.78683893e-02,  6.78693024e-02,  6.78685250e-02,
#         6.78682254e-02,  6.78681786e-02,  6.78668691e-02,  6.78664894e-02,
#         6.78664731e-02,  6.78664731e-02,  6.78664731e-02,  6.78664731e-02,
#         6.78664731e-02,  6.78664731e-02,  6.78664731e-02,  6.78664731e-02,
#         6.78664731e-02,  6.78664731e-02,  6.78664731e-02,  6.78664731e-02]), array([-1.32213711e+01,  2.00326256e+00, -8.89681739e-02,  6.16619333e-01,
#         1.24526967e-01,  1.04615534e-01, -3.27197990e-02,  1.39081426e-02,
#        -1.35681244e-01,  8.92156356e-02,  9.46248229e-02, -3.65824846e-02,
#         1.40738314e-01,  8.45747197e-02,  7.78356780e-02, -2.76866680e-02,
#         6.96858528e-02,  4.69605533e-02,  7.27515505e-02,  9.75700420e-03,
#        -1.24380756e-02,  6.37481853e-02, -3.21401707e-02,  1.48542575e-02,
#         2.30701569e-02,  3.75319387e-02, -1.07303200e-04,  4.41553281e-02,
#         6.22000621e-02,  6.72927429e-02,  5.01854906e-02, -7.76850870e-03,
#         2.63817114e-02, -5.48760759e-03,  2.33964573e-02,  3.26839066e-02,
#         2.02709794e-02, -1.23914318e-02, -5.68312621e-03,  6.86524058e-03,
#         7.94227367e-02,  8.06990028e-02,  8.07937210e-02,  8.09410355e-02,
#         8.14964464e-02,  8.19317071e-02,  8.27602276e-02,  8.30559890e-02,
#         8.24870996e-02,  8.26585951e-02,  8.27925449e-02,  8.00419393e-02,
#         6.70535263e-02,  6.70729672e-02,  6.85543470e-02,  6.93890545e-02,
#         6.73641719e-02,  6.74852106e-02,  6.83997930e-02,  6.79870138e-02,
#         6.81544594e-02,  6.75682014e-02,  6.84119798e-02,  6.77236433e-02,
#         6.76736266e-02,  6.74773114e-02,  6.83352714e-02,  6.90799452e-02,
#         7.05085487e-02,  6.96079486e-02,  6.75586256e-02,  6.73964412e-02,
#         6.76902817e-02,  6.75117763e-02,  6.74243934e-02,  7.01285245e-02,
#         6.93046189e-02,  6.77169581e-02,  6.80263704e-02,  6.88835743e-02,
#         6.73946729e-02,  6.71834715e-02,  6.71553375e-02,  6.71955788e-02,
#         6.71082163e-02,  6.70958764e-02,  6.71224702e-02,  6.70932542e-02,
#         6.70838459e-02,  6.71194249e-02,  6.71074340e-02,  6.70891237e-02,
#         6.71662452e-02,  6.71835554e-02,  6.71685583e-02,  6.75225979e-02,
#         6.76794575e-02,  6.72458925e-02,  6.71470010e-02,  6.71086124e-02,
#         6.70828294e-02,  6.70845062e-02,  6.70748138e-02,  6.70871645e-02,
#         6.70744169e-02,  6.70710350e-02,  6.70695359e-02,  6.70846533e-02,
#         6.70681948e-02,  6.70778801e-02,  6.70745900e-02,  6.70595739e-02,
#         6.70591843e-02,  6.70609485e-02,  6.70696401e-02,  6.70801650e-02,
#         6.70685162e-02,  6.70553660e-02,  6.70555714e-02,  6.70548700e-02,
#         6.70543403e-02,  6.70545426e-02,  6.70574691e-02,  6.70590132e-02,
#         6.70587671e-02,  6.70669838e-02,  6.70731537e-02,  6.70731923e-02,
#         6.70626400e-02,  6.70602848e-02,  6.70597068e-02,  6.70588449e-02,
#         6.70621799e-02,  6.70618128e-02,  6.70611071e-02,  6.70600815e-02,
#         6.70559458e-02,  6.70559269e-02,  6.70573422e-02,  6.70570896e-02,
#         6.70549357e-02,  6.70536807e-02,  6.70534581e-02,  6.70537423e-02,
#         6.70539243e-02,  6.70547982e-02,  6.70559331e-02,  6.70548770e-02,
#         6.70543624e-02,  6.70538454e-02,  6.70538346e-02,  6.70542955e-02,
#         6.70543501e-02,  6.70541243e-02,  6.70546254e-02,  6.70540940e-02,
#         6.70541747e-02,  6.70544815e-02,  6.70539554e-02,  6.70535582e-02,
#         6.70534950e-02,  6.70534346e-02,  6.70535065e-02,  6.70534093e-02,
#         6.70533006e-02,  6.70533304e-02,  6.70531128e-02,  6.70530632e-02,
#         6.70530613e-02,  6.70530613e-02,  6.70530613e-02,  6.70530613e-02,
#         6.70530613e-02,  6.70530613e-02,  6.70530613e-02,  6.70530613e-02,
#         6.70530613e-02,  6.70530613e-02,  6.70530613e-02,  6.70530613e-02]), array([-1.32556037e+01,  1.76991594e+00, -7.73064997e-02,  5.48161828e-01,
#         1.31794610e-01,  1.90402236e-01, -2.24314447e-02, -2.39252706e-02,
#        -1.56809257e-01,  8.44723220e-02,  8.23491237e-02, -2.74007288e-02,
#         1.06872124e-01,  4.64863121e-02,  9.87092918e-02, -2.57949040e-02,
#         5.01088804e-02,  3.83716163e-02,  6.74829628e-02,  1.88881262e-02,
#        -1.50393733e-02,  5.98998614e-02, -1.41880829e-02, -1.09140728e-02,
#        -6.25558973e-03,  4.46595620e-02,  1.12313144e-02,  2.88569449e-02,
#         5.88889376e-02,  6.45006118e-02,  3.31539416e-02,  4.10743127e-03,
#         2.80679072e-02,  2.80694622e-02,  4.98865661e-02,  2.87150112e-02,
#         2.33497039e-02,  7.07936752e-03,  1.99985462e-02,  2.36236619e-02,
#         8.22175935e-02,  8.28433959e-02,  8.38388855e-02,  8.32104083e-02,
#         8.30042144e-02,  8.42324924e-02,  8.48468206e-02,  8.58175239e-02,
#         8.53379904e-02,  8.42996412e-02,  8.39544582e-02,  8.34557028e-02,
#         6.89904810e-02,  6.90055368e-02,  6.99602552e-02,  7.05328298e-02,
#         6.92738881e-02,  6.95007269e-02,  7.03864951e-02,  7.02039997e-02,
#         6.97451203e-02,  6.94637271e-02,  7.01086320e-02,  6.98611811e-02,
#         6.94182765e-02,  7.04150896e-02,  7.54440072e-02,  7.39723879e-02,
#         6.96945771e-02,  6.97343479e-02,  7.09626369e-02,  7.08263005e-02,
#         6.97898540e-02,  7.10544704e-02,  7.12864889e-02,  7.02509221e-02,
#         7.03193860e-02,  7.34794334e-02,  7.14341370e-02,  6.93308274e-02,
#         6.97153349e-02,  6.98679555e-02,  6.91529375e-02,  6.90750551e-02,
#         6.91952679e-02,  6.90459190e-02,  6.90124735e-02,  6.90576516e-02,
#         6.90752378e-02,  6.90351724e-02,  6.90794398e-02,  6.92087444e-02,
#         6.90948978e-02,  6.91756399e-02,  6.95027522e-02,  6.96357441e-02,
#         6.96785279e-02,  6.95293134e-02,  6.92413107e-02,  6.91794104e-02,
#         6.90887598e-02,  6.90617394e-02,  6.90852101e-02,  6.91079050e-02,
#         6.90928153e-02,  6.90425480e-02,  6.90264444e-02,  6.90804872e-02,
#         6.90187415e-02,  6.90209940e-02,  6.90196125e-02,  6.90124184e-02,
#         6.90102047e-02,  6.90257548e-02,  6.90079373e-02,  6.89996992e-02,
#         6.89939728e-02,  6.89937358e-02,  6.89927681e-02,  6.89940482e-02,
#         6.89934434e-02,  6.89936276e-02,  6.90005913e-02,  6.90040174e-02,
#         6.89996667e-02,  6.90085098e-02,  6.90029846e-02,  6.89980954e-02,
#         6.89968256e-02,  6.89976575e-02,  6.89960228e-02,  6.89959912e-02,
#         6.89972694e-02,  6.89975330e-02,  6.89954106e-02,  6.89969677e-02,
#         6.89968839e-02,  6.89959647e-02,  6.89963962e-02,  6.89947337e-02,
#         6.89972873e-02,  6.90030396e-02,  6.89944000e-02,  6.89972936e-02,
#         6.90000950e-02,  6.90015498e-02,  6.90047465e-02,  6.90212148e-02,
#         6.90205054e-02,  6.90194820e-02,  6.90074339e-02,  6.90122670e-02,
#         6.90047806e-02,  6.89950975e-02,  6.89955537e-02,  6.89972001e-02,
#         6.89990438e-02,  6.89958625e-02,  6.89945888e-02,  6.89938347e-02,
#         6.89917897e-02,  6.89912711e-02,  6.89913419e-02,  6.89911292e-02,
#         6.89914569e-02,  6.89911920e-02,  6.89904145e-02,  6.89902013e-02,
#         6.89901909e-02,  6.89901909e-02,  6.89901909e-02,  6.89901909e-02,
#         6.89901909e-02,  6.89901909e-02,  6.89901909e-02,  6.89901909e-02,
#         6.89901909e-02,  6.89901909e-02,  6.89901909e-02,  6.89901909e-02]), array([-1.32240011e+01,  1.91462605e+00, -1.64327100e-01,  7.89662659e-01,
#         6.42357423e-02,  2.49464264e-01, -6.96709518e-02,  2.72306350e-02,
#        -7.36063487e-02,  1.19358003e-01,  1.44400379e-01, -2.02384733e-02,
#         1.58748324e-01,  9.12668873e-02,  1.02954395e-01, -1.48181562e-02,
#         8.87104189e-02,  4.06254835e-02,  1.29289044e-01,  3.14301650e-02,
#        -1.99196927e-02,  8.22040886e-02, -3.94208513e-02,  3.21901334e-02,
#         1.88238408e-02,  2.93439764e-02,  2.39337357e-02,  6.89927458e-02,
#         5.59655166e-02,  9.43885467e-02,  4.91623067e-02, -1.80953997e-02,
#         4.33117691e-02, -6.35193219e-03,  6.91094980e-02,  4.49883648e-02,
#         1.01129697e-02,  3.20044249e-03,  1.17992137e-02,  4.49289068e-02,
#         7.52643975e-02,  7.61637491e-02,  7.57469684e-02,  7.67143721e-02,
#         7.73193238e-02,  7.86274877e-02,  7.94410291e-02,  7.90802429e-02,
#         7.87868423e-02,  7.90626186e-02,  7.76643238e-02,  7.54134393e-02,
#         6.29953473e-02,  6.30115550e-02,  6.50583618e-02,  6.60675719e-02,
#         6.35771723e-02,  6.32335373e-02,  6.35668797e-02,  6.38941191e-02,
#         6.46481841e-02,  6.37758548e-02,  6.36479697e-02,  6.34780641e-02,
#         6.40312342e-02,  6.41571583e-02,  6.38166226e-02,  6.38473774e-02,
#         6.47226111e-02,  6.42718474e-02,  6.41174731e-02,  6.31604363e-02,
#         6.33522737e-02,  6.32645958e-02,  6.30865955e-02,  6.34135377e-02,
#         6.41690394e-02,  6.32999782e-02,  6.31109167e-02,  6.33400866e-02,
#         6.32468419e-02,  6.30359195e-02,  6.30055980e-02,  6.30405716e-02,
#         6.30156837e-02,  6.29989788e-02,  6.30083071e-02,  6.30134756e-02,
#         6.30002182e-02,  6.30088170e-02,  6.30607071e-02,  6.30196526e-02,
#         6.29979104e-02,  6.30467925e-02,  6.30518287e-02,  6.30169780e-02,
#         6.30764671e-02,  6.30370843e-02,  6.30142598e-02,  6.30177863e-02,
#         6.30016162e-02,  6.30066635e-02,  6.30020640e-02,  6.30050054e-02,
#         6.30065806e-02,  6.30010967e-02,  6.30029307e-02,  6.30160906e-02,
#         6.30021836e-02,  6.30178979e-02,  6.30171547e-02,  6.30021161e-02,
#         6.29999348e-02,  6.30005271e-02,  6.29994528e-02,  6.30047332e-02,
#         6.29975016e-02,  6.29961115e-02,  6.29949912e-02,  6.29953490e-02,
#         6.29946121e-02,  6.29940816e-02,  6.29951181e-02,  6.29949530e-02,
#         6.29958297e-02,  6.29998877e-02,  6.30006975e-02,  6.29990815e-02,
#         6.29959111e-02,  6.29961260e-02,  6.29961648e-02,  6.29956789e-02,
#         6.29974704e-02,  6.29986964e-02,  6.29969442e-02,  6.29971223e-02,
#         6.29969497e-02,  6.29962140e-02,  6.29980140e-02,  6.29966380e-02,
#         6.29963992e-02,  6.29945753e-02,  6.29940694e-02,  6.29940001e-02,
#         6.29953494e-02,  6.29968739e-02,  6.29974099e-02,  6.30011628e-02,
#         6.30117446e-02,  6.30161578e-02,  6.30043966e-02,  6.30004576e-02,
#         6.29961398e-02,  6.29971336e-02,  6.29962698e-02,  6.29995272e-02,
#         6.30020823e-02,  6.30054328e-02,  6.29993955e-02,  6.29965654e-02,
#         6.29967396e-02,  6.29949438e-02,  6.29943258e-02,  6.29943156e-02,
#         6.29951961e-02,  6.29942419e-02,  6.29934409e-02,  6.29932305e-02,
#         6.29932185e-02,  6.29932185e-02,  6.29932185e-02,  6.29932185e-02,
#         6.29932185e-02,  6.29932185e-02,  6.29932185e-02,  6.29932185e-02,
#         6.29932185e-02,  6.29932185e-02,  6.29932185e-02,  6.29932185e-02]), array([-1.32191163e+01,  1.97848164e+00,  3.54609715e-02,  7.33250573e-01,
#         1.89855883e-01,  2.73983116e-01, -6.40482481e-02,  3.78907173e-02,
#        -5.37772901e-02,  1.34227017e-01,  1.20494957e-01, -1.66138140e-02,
#         1.61819696e-01,  8.76463563e-02,  1.30435959e-01, -3.52536906e-03,
#         7.16390647e-02,  4.55035161e-02,  9.94568061e-02,  1.59851457e-02,
#        -2.66975311e-02,  8.99798407e-02, -3.13368511e-02,  5.74726503e-03,
#        -1.75630649e-03,  4.86221802e-02,  4.17657498e-02,  4.50934195e-02,
#         7.20531262e-02,  6.75221687e-02,  5.47888920e-02,  1.52090246e-02,
#         5.48568299e-02,  2.82678781e-02,  2.63475298e-02,  3.20576639e-02,
#         1.16671903e-03, -2.37526266e-02, -5.01481613e-03,  2.59676016e-02,
#         7.29106211e-02,  7.43155278e-02,  7.45863450e-02,  7.39849427e-02,
#         7.50257672e-02,  7.53625498e-02,  7.60676715e-02,  7.67243248e-02,
#         7.66625607e-02,  7.56325490e-02,  7.55358978e-02,  7.35847952e-02,
#         6.08742062e-02,  6.08891976e-02,  6.22829233e-02,  6.31866436e-02,
#         6.11268072e-02,  6.11931611e-02,  6.18714962e-02,  6.17259926e-02,
#         6.21219131e-02,  6.13359118e-02,  6.20726520e-02,  6.12380475e-02,
#         6.12750925e-02,  6.16758685e-02,  6.31285058e-02,  6.22163616e-02,
#         6.13797325e-02,  6.21937897e-02,  6.21321002e-02,  6.19468230e-02,
#         6.14420726e-02,  6.17344530e-02,  6.19056823e-02,  6.15536623e-02,
#         6.26362745e-02,  6.22864329e-02,  6.14406805e-02,  6.10568719e-02,
#         6.12631864e-02,  6.10099616e-02,  6.09204282e-02,  6.09746767e-02,
#         6.09592117e-02,  6.08860456e-02,  6.08830167e-02,  6.08993509e-02,
#         6.08904538e-02,  6.08925991e-02,  6.09118517e-02,  6.09101591e-02,
#         6.08899235e-02,  6.09346094e-02,  6.09709933e-02,  6.09822540e-02,
#         6.11626836e-02,  6.09981397e-02,  6.09116421e-02,  6.09091991e-02,
#         6.08984340e-02,  6.09022165e-02,  6.08975741e-02,  6.09034075e-02,
#         6.08910394e-02,  6.08841089e-02,  6.08806265e-02,  6.08918021e-02,
#         6.08867370e-02,  6.08833293e-02,  6.08781723e-02,  6.08786112e-02,
#         6.08767629e-02,  6.08775429e-02,  6.08764985e-02,  6.08778815e-02,
#         6.08757969e-02,  6.08746173e-02,  6.08749442e-02,  6.08748136e-02,
#         6.08747927e-02,  6.08746709e-02,  6.08775809e-02,  6.08781040e-02,
#         6.08762093e-02,  6.08782704e-02,  6.08773302e-02,  6.08765349e-02,
#         6.08751152e-02,  6.08751623e-02,  6.08754061e-02,  6.08746728e-02,
#         6.08758401e-02,  6.08767600e-02,  6.08785220e-02,  6.08886532e-02,
#         6.08880973e-02,  6.08795804e-02,  6.08801532e-02,  6.08854651e-02,
#         6.08770699e-02,  6.08777369e-02,  6.08782341e-02,  6.08782013e-02,
#         6.08783329e-02,  6.08870343e-02,  6.08861113e-02,  6.09022761e-02,
#         6.09023956e-02,  6.08944791e-02,  6.09078522e-02,  6.09180889e-02,
#         6.09044080e-02,  6.09282443e-02,  6.09176334e-02,  6.08882259e-02,
#         6.08820546e-02,  6.08822495e-02,  6.08800534e-02,  6.08786227e-02,
#         6.08803334e-02,  6.08766502e-02,  6.08763010e-02,  6.08750724e-02,
#         6.08748529e-02,  6.08744222e-02,  6.08735464e-02,  6.08732604e-02,
#         6.08732487e-02,  6.08732487e-02,  6.08732487e-02,  6.08732487e-02,
#         6.08732487e-02,  6.08732487e-02,  6.08732487e-02,  6.08732487e-02,
#         6.08732487e-02,  6.08732487e-02,  6.08732487e-02,  6.08732487e-02]), array([-1.32280465e+01,  1.92055216e+00,  1.16286989e-01,  7.38385646e-01,
#         1.36645965e-01,  3.07094550e-01,  2.94291711e-02,  6.45725065e-02,
#        -5.96697075e-02,  1.18037764e-01,  1.24770830e-01,  4.21122670e-02,
#         1.77773654e-01,  9.61189795e-02,  1.63636810e-01,  1.46406350e-02,
#         9.67751970e-02,  6.39748387e-02,  9.36769836e-02,  2.22762712e-02,
#        -3.36513658e-03,  9.38994036e-02, -1.10159342e-02,  2.41348916e-02,
#         1.47105599e-02,  5.42464102e-02,  1.11678386e-02,  4.72992393e-02,
#         6.55995840e-02,  6.58380036e-02,  6.51926137e-02,  7.74518365e-03,
#         5.00391541e-02,  2.87009629e-02,  5.14382676e-02,  4.23152820e-02,
#         2.32445065e-02,  1.06257078e-02,  2.09795979e-02,  3.38953259e-02,
#         7.09611501e-02,  7.11438992e-02,  7.12606833e-02,  7.14649476e-02,
#         7.20956977e-02,  7.31730211e-02,  7.32467929e-02,  7.28634754e-02,
#         7.22793910e-02,  7.32365325e-02,  7.22876990e-02,  7.05223466e-02,
#         5.75754470e-02,  5.76025636e-02,  5.96156338e-02,  5.99355242e-02,
#         5.79369524e-02,  5.81615338e-02,  5.93345304e-02,  5.82680143e-02,
#         5.82606628e-02,  5.82565800e-02,  5.80885496e-02,  5.78016790e-02,
#         5.80434562e-02,  5.86464981e-02,  5.89731832e-02,  5.84679054e-02,
#         5.90950557e-02,  5.88186805e-02,  5.82372902e-02,  5.87628820e-02,
#         5.91298179e-02,  5.85971723e-02,  5.94682608e-02,  5.91259561e-02,
#         5.80494340e-02,  5.89378494e-02,  5.92482098e-02,  5.79550672e-02,
#         5.76511672e-02,  5.77024846e-02,  5.76412632e-02,  5.76202490e-02,
#         5.76089610e-02,  5.75924515e-02,  5.75898242e-02,  5.75948104e-02,
#         5.75988115e-02,  5.76143936e-02,  5.76475220e-02,  5.76186777e-02,
#         5.75996884e-02,  5.76668158e-02,  5.77720471e-02,  5.77654433e-02,
#         5.77654837e-02,  5.76815118e-02,  5.76312614e-02,  5.76308799e-02,
#         5.75867748e-02,  5.76009964e-02,  5.76071369e-02,  5.75876538e-02,
#         5.75890241e-02,  5.75882361e-02,  5.75785528e-02,  5.75834391e-02,
#         5.75848716e-02,  5.75771373e-02,  5.75794942e-02,  5.75801239e-02,
#         5.75756249e-02,  5.75761208e-02,  5.75742495e-02,  5.75735862e-02,
#         5.75728184e-02,  5.75726714e-02,  5.75734818e-02,  5.75728104e-02,
#         5.75728358e-02,  5.75732673e-02,  5.75753767e-02,  5.75745272e-02,
#         5.75737803e-02,  5.75753967e-02,  5.75775944e-02,  5.75797001e-02,
#         5.75742585e-02,  5.75734566e-02,  5.75732251e-02,  5.75730161e-02,
#         5.75744113e-02,  5.75756032e-02,  5.75811320e-02,  5.75919573e-02,
#         5.75885692e-02,  5.75821089e-02,  5.75799482e-02,  5.75848561e-02,
#         5.75789634e-02,  5.75759965e-02,  5.75789244e-02,  5.75801852e-02,
#         5.75830126e-02,  5.75873801e-02,  5.75894352e-02,  5.75824417e-02,
#         5.75908331e-02,  5.75946450e-02,  5.76077852e-02,  5.75955377e-02,
#         5.75871786e-02,  5.75829064e-02,  5.75843148e-02,  5.75904086e-02,
#         5.75794926e-02,  5.75800123e-02,  5.75790352e-02,  5.75755718e-02,
#         5.75749480e-02,  5.75738863e-02,  5.75733587e-02,  5.75729713e-02,
#         5.75730462e-02,  5.75727105e-02,  5.75719812e-02,  5.75717732e-02,
#         5.75717656e-02,  5.75717656e-02,  5.75717656e-02,  5.75717656e-02,
#         5.75717656e-02,  5.75717656e-02,  5.75717656e-02,  5.75717656e-02,
#         5.75717656e-02,  5.75717656e-02,  5.75717656e-02,  5.75717656e-02]), array([-1.32178862e+01,  1.96068588e+00, -2.22345581e-01,  7.36785690e-01,
#         8.81707027e-02,  1.67498436e-01, -6.09471591e-02, -6.19336463e-02,
#        -1.37022595e-01,  1.09476315e-01,  1.23694914e-01, -6.56759666e-02,
#         1.25340695e-01,  6.07031178e-02,  7.59673730e-02, -3.17528672e-02,
#         4.66338877e-02,  3.80263665e-02,  8.30266649e-02,  2.02380913e-02,
#        -2.62291022e-02,  8.25316759e-02, -5.29704225e-02, -1.40069773e-02,
#         2.47843315e-03, -4.60501794e-03,  9.37902675e-04,  4.11356737e-02,
#         7.25835730e-02,  7.40278415e-02,  3.76323311e-02,  5.57161753e-03,
#         3.27848569e-02,  8.68460267e-03,  5.93576869e-02,  3.94575309e-02,
#         1.05915481e-02, -1.36241153e-02, -1.66950059e-02,  2.18866981e-02,
#         8.01388408e-02,  8.10395684e-02,  8.16837526e-02,  8.15809762e-02,
#         8.32931160e-02,  8.33273000e-02,  8.47913975e-02,  8.50204870e-02,
#         8.54623250e-02,  8.56803143e-02,  8.45908230e-02,  8.22735404e-02,
#         6.85556515e-02,  6.85708108e-02,  7.03508288e-02,  7.12459868e-02,
#         6.87921493e-02,  6.87665626e-02,  6.93855699e-02,  7.03666115e-02,
#         6.96164065e-02,  6.89159542e-02,  6.93193866e-02,  6.94374261e-02,
#         6.94232764e-02,  6.88620658e-02,  6.89606657e-02,  7.05447775e-02,
#         7.22028848e-02,  6.96065763e-02,  6.87004626e-02,  6.86491290e-02,
#         6.89868941e-02,  6.87336672e-02,  6.86001719e-02,  7.01087100e-02,
#         7.02540756e-02,  6.86417745e-02,  6.87667985e-02,  6.97491848e-02,
#         6.87088930e-02,  6.85895251e-02,  6.86119100e-02,  6.85968129e-02,
#         6.85669922e-02,  6.85713692e-02,  6.85879262e-02,  6.85645177e-02,
#         6.85625309e-02,  6.85784688e-02,  6.85804205e-02,  6.85611229e-02,
#         6.85680293e-02,  6.85794878e-02,  6.85646812e-02,  6.86602391e-02,
#         6.88571283e-02,  6.85883238e-02,  6.85892275e-02,  6.86016813e-02,
#         6.85614533e-02,  6.85656692e-02,  6.85636496e-02,  6.85658489e-02,
#         6.85701153e-02,  6.85660971e-02,  6.85650656e-02,  6.85655881e-02,
#         6.85679908e-02,  6.85635770e-02,  6.85651076e-02,  6.85629511e-02,
#         6.85585896e-02,  6.85579697e-02,  6.85589739e-02,  6.85606058e-02,
#         6.85576107e-02,  6.85564660e-02,  6.85562931e-02,  6.85565700e-02,
#         6.85561636e-02,  6.85558919e-02,  6.85565708e-02,  6.85568198e-02,
#         6.85571913e-02,  6.85609720e-02,  6.85649533e-02,  6.85603520e-02,
#         6.85584800e-02,  6.85587335e-02,  6.85589483e-02,  6.85581028e-02,
#         6.85599730e-02,  6.85625457e-02,  6.85597927e-02,  6.85590177e-02,
#         6.85582077e-02,  6.85579656e-02,  6.85602854e-02,  6.85592555e-02,
#         6.85576558e-02,  6.85562672e-02,  6.85560242e-02,  6.85561644e-02,
#         6.85560003e-02,  6.85563364e-02,  6.85573421e-02,  6.85585957e-02,
#         6.85586915e-02,  6.85592656e-02,  6.85577643e-02,  6.85581142e-02,
#         6.85576987e-02,  6.85583679e-02,  6.85580112e-02,  6.85595253e-02,
#         6.85608206e-02,  6.85610364e-02,  6.85591555e-02,  6.85577960e-02,
#         6.85562979e-02,  6.85562593e-02,  6.85560830e-02,  6.85560236e-02,
#         6.85558815e-02,  6.85557718e-02,  6.85554468e-02,  6.85553547e-02,
#         6.85553501e-02,  6.85553500e-02,  6.85553500e-02,  6.85553500e-02,
#         6.85553500e-02,  6.85553500e-02,  6.85553500e-02,  6.85553500e-02,
#         6.85553500e-02,  6.85553500e-02,  6.85553500e-02,  6.85553500e-02]), array([-1.32253859e+01,  1.92086751e+00, -1.89408688e-01,  7.21167390e-01,
#         1.46611003e-01,  1.46409750e-01, -2.74021734e-02, -2.74794340e-02,
#        -1.61321395e-01,  1.23511883e-01,  8.85052627e-02, -3.90221594e-02,
#         1.56293178e-01,  8.67495959e-02,  1.12399962e-01, -2.26548827e-02,
#         7.27683455e-02,  5.21421317e-02,  8.49729788e-02, -1.02712088e-02,
#        -2.57704068e-02,  9.73803901e-02, -3.33802376e-02, -1.76377586e-02,
#        -3.64674067e-03,  2.42607168e-02, -3.62145609e-03,  4.63364895e-02,
#         6.02352088e-02,  8.80987435e-02,  5.12268377e-02, -1.50717509e-02,
#         3.45745196e-02, -5.15761021e-03,  5.63060318e-02,  5.46278524e-02,
#         3.14687180e-02, -8.84416173e-03, -3.04200855e-04,  4.64558113e-02,
#         7.75304403e-02,  7.81814128e-02,  8.01226765e-02,  8.03542012e-02,
#         8.06342872e-02,  8.10548194e-02,  8.24375632e-02,  8.35126818e-02,
#         8.33388416e-02,  8.30870546e-02,  8.24259729e-02,  7.98016551e-02,
#         6.63778012e-02,  6.63962265e-02,  6.71567209e-02,  6.81992695e-02,
#         6.69008078e-02,  6.66931487e-02,  6.73881073e-02,  6.79022704e-02,
#         6.81623160e-02,  6.68231729e-02,  6.68249442e-02,  6.69506919e-02,
#         6.70297609e-02,  6.73491772e-02,  7.11735972e-02,  7.02255505e-02,
#         6.75329916e-02,  6.77909572e-02,  6.82432834e-02,  6.77368025e-02,
#         6.73443755e-02,  6.75110363e-02,  6.76251267e-02,  6.81300834e-02,
#         6.78050628e-02,  7.08241819e-02,  6.95716736e-02,  6.70906579e-02,
#         6.66270872e-02,  6.64351058e-02,  6.64400577e-02,  6.65572151e-02,
#         6.64192283e-02,  6.64305325e-02,  6.64612777e-02,  6.64187087e-02,
#         6.64676752e-02,  6.64816655e-02,  6.64428080e-02,  6.64222545e-02,
#         6.64533524e-02,  6.64586799e-02,  6.65540807e-02,  6.70179074e-02,
#         6.70688020e-02,  6.66274214e-02,  6.64835445e-02,  6.64201746e-02,
#         6.64390484e-02,  6.64178611e-02,  6.64353778e-02,  6.64604935e-02,
#         6.64462543e-02,  6.64537872e-02,  6.64208287e-02,  6.64161777e-02,
#         6.64068373e-02,  6.63984332e-02,  6.63970394e-02,  6.63853824e-02,
#         6.63864739e-02,  6.63913160e-02,  6.63843412e-02,  6.63826607e-02,
#         6.63792359e-02,  6.63787932e-02,  6.63801404e-02,  6.63795603e-02,
#         6.63795214e-02,  6.63796738e-02,  6.63857970e-02,  6.63863002e-02,
#         6.63852083e-02,  6.63905190e-02,  6.63891533e-02,  6.63860575e-02,
#         6.63833701e-02,  6.63808571e-02,  6.63800166e-02,  6.63798435e-02,
#         6.63818065e-02,  6.63829006e-02,  6.63835675e-02,  6.63853107e-02,
#         6.63844131e-02,  6.63842437e-02,  6.63855242e-02,  6.63830373e-02,
#         6.63808193e-02,  6.63790399e-02,  6.63800996e-02,  6.63810971e-02,
#         6.63817931e-02,  6.63816373e-02,  6.63832720e-02,  6.63835689e-02,
#         6.63872773e-02,  6.63915525e-02,  6.63917255e-02,  6.63891005e-02,
#         6.63856243e-02,  6.63843078e-02,  6.63858075e-02,  6.63890628e-02,
#         6.63916499e-02,  6.63899942e-02,  6.63825032e-02,  6.63815187e-02,
#         6.63803276e-02,  6.63809987e-02,  6.63803311e-02,  6.63802603e-02,
#         6.63800560e-02,  6.63792989e-02,  6.63774874e-02,  6.63772085e-02,
#         6.63771925e-02,  6.63771925e-02,  6.63771925e-02,  6.63771925e-02,
#         6.63771925e-02,  6.63771925e-02,  6.63771925e-02,  6.63771925e-02,
#         6.63771925e-02,  6.63771925e-02,  6.63771925e-02,  6.63771925e-02]), array([-1.32527922e+01,  1.74946753e+00, -2.34358180e-01,  5.85242636e-01,
#         7.69805200e-02,  7.14598888e-02, -6.36381367e-02, -1.66502506e-03,
#        -1.74870749e-01,  9.57744934e-02,  3.67779044e-02, -7.84540509e-02,
#         1.24961356e-01, -3.99075344e-03,  3.77651131e-02, -6.17467541e-02,
#         3.22516280e-02,  2.16693644e-02,  4.98666715e-02, -2.30145607e-03,
#        -1.14579989e-02,  6.29588294e-02, -4.66717016e-02,  2.25280018e-03,
#         1.27916245e-02,  3.05105499e-02,  1.17612863e-02,  4.70833116e-02,
#         5.21289317e-02,  4.96859217e-02,  2.51920260e-02,  2.26128008e-02,
#         4.36259146e-02,  1.15511489e-03,  4.88570058e-02,  3.63572452e-02,
#         2.48901369e-02,  3.05959897e-03,  1.93996983e-02,  2.40880557e-02,
#         8.65479502e-02,  8.75785080e-02,  8.70903046e-02,  8.76779506e-02,
#         8.85486206e-02,  8.76284322e-02,  8.88808133e-02,  9.00621409e-02,
#         9.05030067e-02,  9.15508793e-02,  8.93745185e-02,  8.68332923e-02,
#         7.31864739e-02,  7.31947797e-02,  7.38639118e-02,  7.51975118e-02,
#         7.53495146e-02,  7.51923651e-02,  7.41770428e-02,  7.68415434e-02,
#         7.62907859e-02,  7.71575897e-02,  7.89483224e-02,  7.54533370e-02,
#         7.47760906e-02,  7.41879778e-02,  8.27494227e-02,  8.06721669e-02,
#         8.03946399e-02,  7.56316420e-02,  7.38212411e-02,  7.39017392e-02,
#         7.69025371e-02,  7.55791111e-02,  7.37688204e-02,  7.43857229e-02,
#         7.92416770e-02,  7.91261033e-02,  7.50972162e-02,  7.42716863e-02,
#         8.02583561e-02,  7.82186520e-02,  7.33942802e-02,  7.32749384e-02,
#         7.34596038e-02,  7.37897328e-02,  7.32849377e-02,  7.33294391e-02,
#         7.32975129e-02,  7.34021777e-02,  7.33773673e-02,  7.33523600e-02,
#         7.33149002e-02,  7.46208213e-02,  7.38184922e-02,  7.33490468e-02,
#         7.36084918e-02,  7.41314979e-02,  7.35702602e-02,  7.33522307e-02,
#         7.35424278e-02,  7.32577785e-02,  7.32790143e-02,  7.33986805e-02,
#         7.33307776e-02,  7.32287185e-02,  7.32518931e-02,  7.32308698e-02,
#         7.32747143e-02,  7.32338665e-02,  7.32464318e-02,  7.32816502e-02,
#         7.32181006e-02,  7.32290275e-02,  7.32671313e-02,  7.33684133e-02,
#         7.33352923e-02,  7.32310858e-02,  7.32038781e-02,  7.32010062e-02,
#         7.31951882e-02,  7.31927447e-02,  7.32077265e-02,  7.32109122e-02,
#         7.32108352e-02,  7.32218031e-02,  7.32356725e-02,  7.32303188e-02,
#         7.32299084e-02,  7.32279194e-02,  7.32114869e-02,  7.32076788e-02,
#         7.32106011e-02,  7.32206367e-02,  7.32267047e-02,  7.32213055e-02,
#         7.32185802e-02,  7.31958754e-02,  7.31984887e-02,  7.32016795e-02,
#         7.31981730e-02,  7.31915641e-02,  7.31880611e-02,  7.31874978e-02,
#         7.31876082e-02,  7.31884988e-02,  7.31925423e-02,  7.31982617e-02,
#         7.31959635e-02,  7.32028609e-02,  7.31936328e-02,  7.31940622e-02,
#         7.31916158e-02,  7.31898110e-02,  7.31908603e-02,  7.31922663e-02,
#         7.31934737e-02,  7.31932347e-02,  7.31920196e-02,  7.31927962e-02,
#         7.31898252e-02,  7.31888259e-02,  7.31889397e-02,  7.31881058e-02,
#         7.31875448e-02,  7.31877355e-02,  7.31863148e-02,  7.31859944e-02,
#         7.31859711e-02,  7.31859711e-02,  7.31859711e-02,  7.31859711e-02,
#         7.31859711e-02,  7.31859711e-02,  7.31859711e-02,  7.31859711e-02,
#         7.31859711e-02,  7.31859711e-02,  7.31859711e-02,  7.31859711e-02]), array([-1.31936315e+01,  2.08044537e+00, -3.21232197e-01,  7.82858882e-01,
#         6.20917309e-02,  2.62857282e-01, -1.47024529e-01, -3.86083347e-02,
#        -1.28505706e-01,  8.48119678e-02,  7.06724297e-02, -5.20711293e-02,
#         1.50953881e-01,  5.48072202e-02,  1.42064123e-01, -3.49273389e-02,
#         8.30498547e-02,  2.67933378e-02,  7.89198973e-02, -1.17791066e-02,
#        -3.00185659e-02,  1.26689065e-01, -4.86450074e-02,  1.54918305e-02,
#        -4.01280076e-03,  2.46201095e-02,  6.04165096e-03,  3.24135993e-02,
#         7.05187876e-02,  9.85978850e-02,  5.31771341e-02, -2.62127423e-02,
#         5.67737326e-02,  1.57642035e-02,  4.11118686e-02,  3.14534030e-02,
#         3.09722448e-02,  1.41593133e-02,  2.17111503e-03,  3.37959003e-02,
#         7.80947737e-02,  7.91542108e-02,  7.98465493e-02,  7.98706671e-02,
#         8.01688869e-02,  8.13760163e-02,  8.19586994e-02,  8.21987669e-02,
#         8.13915490e-02,  8.18431222e-02,  8.23991819e-02,  7.98822558e-02,
#         6.64676339e-02,  6.64859627e-02,  6.88029247e-02,  6.96942646e-02,
#         6.67625966e-02,  6.68871632e-02,  6.77820812e-02,  6.75275199e-02,
#         6.81155806e-02,  6.70676439e-02,  6.72524176e-02,  6.67220864e-02,
#         6.72004074e-02,  6.76667299e-02,  6.82495384e-02,  6.78699709e-02,
#         6.73311878e-02,  6.79548358e-02,  6.70869742e-02,  6.72393044e-02,
#         6.68330055e-02,  6.68645490e-02,  6.75146697e-02,  6.69796074e-02,
#         6.66769477e-02,  6.72890816e-02,  6.72783096e-02,  6.65571087e-02,
#         6.65461701e-02,  6.66245246e-02,  6.65137863e-02,  6.64869537e-02,
#         6.65054437e-02,  6.64843472e-02,  6.64782466e-02,  6.64898709e-02,
#         6.64779260e-02,  6.64771952e-02,  6.64987469e-02,  6.64870212e-02,
#         6.64735138e-02,  6.64987217e-02,  6.64957098e-02,  6.64992684e-02,
#         6.66105100e-02,  6.65250924e-02,  6.65117296e-02,  6.65096584e-02,
#         6.64827689e-02,  6.64863380e-02,  6.64846733e-02,  6.64808917e-02,
#         6.64854108e-02,  6.64797787e-02,  6.64814166e-02,  6.64875831e-02,
#         6.64808781e-02,  6.64770073e-02,  6.64888911e-02,  6.64805514e-02,
#         6.64736193e-02,  6.64749767e-02,  6.64730623e-02,  6.64736466e-02,
#         6.64689855e-02,  6.64685518e-02,  6.64688085e-02,  6.64696649e-02,
#         6.64684505e-02,  6.64684877e-02,  6.64712907e-02,  6.64724994e-02,
#         6.64705128e-02,  6.64741880e-02,  6.64720539e-02,  6.64710663e-02,
#         6.64703296e-02,  6.64690930e-02,  6.64688212e-02,  6.64689959e-02,
#         6.64692223e-02,  6.64697602e-02,  6.64719675e-02,  6.64722343e-02,
#         6.64705624e-02,  6.64744460e-02,  6.64727621e-02,  6.64740133e-02,
#         6.64763701e-02,  6.64704912e-02,  6.64690230e-02,  6.64695400e-02,
#         6.64723152e-02,  6.64767164e-02,  6.64867271e-02,  6.64824326e-02,
#         6.64986748e-02,  6.64940977e-02,  6.65065604e-02,  6.65133504e-02,
#         6.65085726e-02,  6.64865533e-02,  6.64838845e-02,  6.64798902e-02,
#         6.64836612e-02,  6.64811588e-02,  6.64791096e-02,  6.64741357e-02,
#         6.64728628e-02,  6.64732845e-02,  6.64723883e-02,  6.64711163e-02,
#         6.64706346e-02,  6.64687924e-02,  6.64677420e-02,  6.64672091e-02,
#         6.64671946e-02,  6.64671946e-02,  6.64671946e-02,  6.64671946e-02,
#         6.64671946e-02,  6.64671946e-02,  6.64671946e-02,  6.64671946e-02,
#         6.64671946e-02,  6.64671946e-02,  6.64671946e-02,  6.64671946e-02]), array([-1.32303001e+01,  1.85473727e+00, -3.66501318e-01,  6.14084518e-01,
#         1.75297418e-02,  1.63529214e-01, -1.74626875e-01, -5.27031451e-02,
#        -1.81507361e-01,  7.69826255e-02,  3.36199522e-02, -9.71931257e-02,
#         1.14868644e-01,  8.71512177e-04,  7.68007529e-02, -8.04341527e-02,
#         1.54223828e-02,  7.33172049e-04,  3.30741440e-02, -4.54047121e-02,
#        -5.17534278e-02,  6.43096169e-02, -4.12740659e-02, -1.74848897e-02,
#         1.68236695e-02,  5.42293819e-02,  6.52678784e-03,  4.83258899e-02,
#         4.68164668e-02,  7.31852357e-02,  1.85613787e-02,  1.38376318e-02,
#         3.41534200e-02,  4.50805199e-03,  7.47437358e-02,  1.98982704e-02,
#         3.06669426e-02, -1.52276407e-02,  8.11168287e-03,  2.85457777e-02,
#         8.82378617e-02,  8.82051138e-02,  8.88700148e-02,  8.93423438e-02,
#         8.93355069e-02,  9.02149804e-02,  9.03934011e-02,  9.04566920e-02,
#         9.10072858e-02,  9.17649183e-02,  9.17793039e-02,  8.96006581e-02,
#         7.50115509e-02,  7.50155955e-02,  7.54317293e-02,  7.67019468e-02,
#         7.71195323e-02,  7.92426022e-02,  7.65210135e-02,  7.78924735e-02,
#         8.86122302e-02,  7.87884371e-02,  7.69983840e-02,  7.85231002e-02,
#         7.99775441e-02,  7.84052743e-02,  7.64944246e-02,  7.69263885e-02,
#         7.83854037e-02,  8.38807577e-02,  7.94382247e-02,  7.76705595e-02,
#         7.68034987e-02,  7.79502735e-02,  8.17669915e-02,  8.24135333e-02,
#         7.87029737e-02,  7.86332338e-02,  8.43803698e-02,  8.10984618e-02,
#         7.78763119e-02,  7.71368087e-02,  7.57929705e-02,  7.52911020e-02,
#         7.51822909e-02,  7.52288316e-02,  7.53214723e-02,  7.52683382e-02,
#         7.52760722e-02,  7.52732119e-02,  7.53722308e-02,  7.54500643e-02,
#         7.53790019e-02,  7.55830738e-02,  7.58392240e-02,  7.61605309e-02,
#         7.61712758e-02,  7.58269123e-02,  7.58910489e-02,  7.54991641e-02,
#         7.51505860e-02,  7.52446538e-02,  7.52516141e-02,  7.52308779e-02,
#         7.52661861e-02,  7.51518225e-02,  7.50631669e-02,  7.51488585e-02,
#         7.50947483e-02,  7.51133269e-02,  7.51382301e-02,  7.51166102e-02,
#         7.51320220e-02,  7.51359246e-02,  7.50879695e-02,  7.50724952e-02,
#         7.50780401e-02,  7.50289705e-02,  7.50260224e-02,  7.50227602e-02,
#         7.50213188e-02,  7.50201588e-02,  7.50369924e-02,  7.50473718e-02,
#         7.50458043e-02,  7.50976379e-02,  7.51413850e-02,  7.51189414e-02,
#         7.50549287e-02,  7.50425044e-02,  7.50375875e-02,  7.50357955e-02,
#         7.50372885e-02,  7.50410491e-02,  7.50401926e-02,  7.50504316e-02,
#         7.50554946e-02,  7.50292604e-02,  7.50319517e-02,  7.50316825e-02,
#         7.50328157e-02,  7.50251881e-02,  7.50199184e-02,  7.50221057e-02,
#         7.50371711e-02,  7.50409472e-02,  7.50481696e-02,  7.51481324e-02,
#         7.51474795e-02,  7.51020798e-02,  7.51301611e-02,  7.52435953e-02,
#         7.51539009e-02,  7.51136372e-02,  7.51603796e-02,  7.51483416e-02,
#         7.51734274e-02,  7.51466244e-02,  7.51134206e-02,  7.50909090e-02,
#         7.50490237e-02,  7.50517178e-02,  7.50568913e-02,  7.50437682e-02,
#         7.50413154e-02,  7.50250443e-02,  7.50134822e-02,  7.50113543e-02,
#         7.50112319e-02,  7.50112317e-02,  7.50112317e-02,  7.50112317e-02,
#         7.50112317e-02,  7.50112317e-02,  7.50112317e-02,  7.50112317e-02,
#         7.50112317e-02,  7.50112317e-02,  7.50112317e-02,  7.50112317e-02]), array([-1.32355552e+01,  1.83359086e+00, -3.50140918e-01,  6.45688278e-01,
#         1.61243831e-01,  7.64686682e-02, -6.18408488e-02,  5.13805136e-02,
#        -2.06821482e-01,  1.29762703e-01,  6.61130526e-02, -9.41281735e-02,
#         1.44915438e-01,  2.77728167e-02,  7.04541972e-02, -4.95651744e-02,
#         3.92210344e-02, -1.23385532e-03,  6.40244933e-02,  8.06088253e-03,
#        -2.44144411e-02,  7.64184068e-02, -1.76824455e-02,  4.20894502e-03,
#         8.35587023e-03,  2.81832690e-02, -9.19340276e-04,  6.75814658e-02,
#         5.61682153e-02,  6.65840423e-02,  2.91408542e-02,  1.63007992e-02,
#         4.61300341e-02, -9.73484010e-03,  4.15690957e-02,  2.62868366e-02,
# ...
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351]), array([-13.37908816,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351]), array([-13.37908816,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351]), array([-13.37908816,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351]), array([-13.37908816,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351,
#          0.07474351,   0.07474351,   0.07474351,   0.07474351])]
# ['neutral/calm_male', 'neutral/calm_male', 'neutral/calm_male', 'neutral/calm_male', 'neutral/calm_male', 'neutral/calm_male', 'happy_male', 'neutral/calm_male', 'neutral/calm_male', 'happy_male', 'happy_male', 'neutral/calm_male', 'happy_male', 'neutral/calm_male', 'neutral/calm_male', 'neutral/calm_male', 'happy_male', 'happy_male', 'happy_male', 'neutral/calm_male', 'happy_male', 'neutral/calm_male', 'neutral/calm_male', 'neutral/calm_male', 'happy_male', 'happy_male', 'happy_male', 'happy_male', 'neutral/calm_male', 'neutral/calm_male', 'neutral/calm_male', 'neutral/calm_male', 'happy_male', 'happy_male', 'happy_male', 'happy_male', 'neutral/calm_male', 'neutral/calm_male', 'neutral/calm_male', 'neutral/calm_male', 'happy_male', 'happy_male', 'happy_male', 'happy_male', 'neutral/calm_male', 'neutral/calm_male', 'neutral/calm_male', 'neutral/calm_male', 'happy_male', 'happy_male', 'happy_male', 'happy_male', 'neutral/calm_male', 'neutral/calm_male', 'neutral/calm_male', 'neutral/calm_male', 'happy_male', 'happy_male', 'happy_male', 'happy_male', 'neutral/calm_male', 'neutral/calm_male', 'neutral/calm_male', 'neutral/calm_male', 'neutral/calm_male', 'neutral/calm_male', 'happy_male', 'neutral/calm_male', 'neutral/calm_male', 'happy_male', 'neutral/calm_male', 'happy_male', 'happy_male', 'happy_male', 'neutral/calm_male', 'neutral/calm_male', 'neutral/calm_male', 'happy_male', 'happy_male', 'happy_male', 'neutral/calm_male', 'neutral/calm_male', 'neutral/calm_male', 'happy_male', 'neutral/calm_male', 'happy_male', 'neutral/calm_male', 'happy_male', 'happy_male', 'neutral/calm_male', 'neutral/calm_male', 'happy_male', 'neutral/calm_male', 'neutral/calm_female', 'neutral/calm_female', 'neutral/calm_female', 'neutral/calm_female', 'neutral/calm_female', 'neutral/calm_female', 'neutral/calm_female', 'neutral/calm_female', 'happy_female', 'happy_female', 'happy_female', 'happy_female', 'neutral/calm_female', 'neutral/calm_female', 'neutral/calm_female', 'neutral/calm_female', 'happy_female', 'happy_female', 'happy_female', 'neutral/calm_female', 'neutral/calm_female', 'happy_female', 'happy_female', 'neutral/calm_female', 'happy_female', 'neutral/calm_female', 'happy_female', 'neutral/calm_female', 'happy_female', 'happy_female', 'neutral/calm_female', 'neutral/calm_female', 'neutral/calm_female', 'happy_female', 'happy_female', 'happy_female', 'neutral/calm_female', 'neutral/calm_female', 'neutral/calm_female', 'neutral/calm_female', 'happy_female', 'happy_female', 'happy_female', 'happy_female', 'neutral/calm_female', 'neutral/calm_female', 'neutral/calm_female', 'neutral/calm_female', 'happy_female', 'happy_female', 'happy_female', 'happy_female', 'neutral/calm_female', 'neutral/calm_female', 'neutral/calm_female', 'happy_female', 'happy_female', 'neutral/calm_female', 'happy_female', 'neutral/calm_female', 'happy_female', 'neutral/calm_female', 'neutral/calm_female', 'neutral/calm_female', 'neutral/calm_female', 'neutral/calm_female', 'happy_female', 'neutral/calm_female', 'happy_female', 'neutral/calm_female', 'neutral/calm_female', 'neutral/calm_female', 'happy_female', 'happy_female', 'happy_female', 'neutral/calm_female', 'happy_female', 'neutral/calm_female', 'neutral/calm_female', 'neutral/calm_female', 'happy_female', 'happy_female', 'neutral/calm_female', 'happy_female', 'happy_female', 'neutral/calm_female', 'neutral/calm_female', 'happy_female', 'happy_female', 'neutral/calm_female', 'neutral/calm_female', 'neutral/calm_female', 'happy_female', 'happy_female', 'neutral/calm_female', 'happy_female', 'happy_female', 'neutral/calm_female', 'happy_female', 'neutral/calm_female', 'neutral/calm_female', 'happy_female', 'happy_female', 'happy_female', 'neutral/calm_female', 'neutral/calm_female', 'neutral/calm_female', 'neutral/calm_female', 'happy_female', 'happy_female', 'happy_female', 'neutral/calm_female', 'happy_female', 'neutral/calm_female', 'neutral/calm_female', 'neutral/calm_female', 'happy_female', 'happy_female ...

# %%
print(y)
# Out:
# ['neutral/calm_male', 'neutral/calm_male', 'neutral/calm_male', 'neutral/calm_male', 'neutral/calm_male', 'neutral/calm_male', 'happy_male', 'neutral/calm_male', 'neutral/calm_male', 'happy_male', 'happy_male', 'neutral/calm_male', 'happy_male', 'neutral/calm_male', 'neutral/calm_male', 'neutral/calm_male', 'happy_male', 'happy_male', 'happy_male', 'neutral/calm_male', 'happy_male', 'neutral/calm_male', 'neutral/calm_male', 'neutral/calm_male', 'happy_male', 'happy_male', 'happy_male', 'happy_male', 'neutral/calm_male', 'neutral/calm_male', 'neutral/calm_male', 'neutral/calm_male', 'happy_male', 'happy_male', 'happy_male', 'happy_male', 'neutral/calm_male', 'neutral/calm_male', 'neutral/calm_male', 'neutral/calm_male', 'happy_male', 'happy_male', 'happy_male', 'happy_male', 'neutral/calm_male', 'neutral/calm_male', 'neutral/calm_male', 'neutral/calm_male', 'happy_male', 'happy_male', 'happy_male', 'happy_male', 'neutral/calm_male', 'neutral/calm_male', 'neutral/calm_male', 'neutral/calm_male', 'happy_male', 'happy_male', 'happy_male', 'happy_male', 'neutral/calm_male', 'neutral/calm_male', 'neutral/calm_male', 'neutral/calm_male', 'neutral/calm_male', 'neutral/calm_male', 'happy_male', 'neutral/calm_male', 'neutral/calm_male', 'happy_male', 'neutral/calm_male', 'happy_male', 'happy_male', 'happy_male', 'neutral/calm_male', 'neutral/calm_male', 'neutral/calm_male', 'happy_male', 'happy_male', 'happy_male', 'neutral/calm_male', 'neutral/calm_male', 'neutral/calm_male', 'happy_male', 'neutral/calm_male', 'happy_male', 'neutral/calm_male', 'happy_male', 'happy_male', 'neutral/calm_male', 'neutral/calm_male', 'happy_male', 'neutral/calm_male', 'neutral/calm_female', 'neutral/calm_female', 'neutral/calm_female', 'neutral/calm_female', 'neutral/calm_female', 'neutral/calm_female', 'neutral/calm_female', 'neutral/calm_female', 'happy_female', 'happy_female', 'happy_female', 'happy_female', 'neutral/calm_female', 'neutral/calm_female', 'neutral/calm_female', 'neutral/calm_female', 'happy_female', 'happy_female', 'happy_female', 'neutral/calm_female', 'neutral/calm_female', 'happy_female', 'happy_female', 'neutral/calm_female', 'happy_female', 'neutral/calm_female', 'happy_female', 'neutral/calm_female', 'happy_female', 'happy_female', 'neutral/calm_female', 'neutral/calm_female', 'neutral/calm_female', 'happy_female', 'happy_female', 'happy_female', 'neutral/calm_female', 'neutral/calm_female', 'neutral/calm_female', 'neutral/calm_female', 'happy_female', 'happy_female', 'happy_female', 'happy_female', 'neutral/calm_female', 'neutral/calm_female', 'neutral/calm_female', 'neutral/calm_female', 'happy_female', 'happy_female', 'happy_female', 'happy_female', 'neutral/calm_female', 'neutral/calm_female', 'neutral/calm_female', 'happy_female', 'happy_female', 'neutral/calm_female', 'happy_female', 'neutral/calm_female', 'happy_female', 'neutral/calm_female', 'neutral/calm_female', 'neutral/calm_female', 'neutral/calm_female', 'neutral/calm_female', 'happy_female', 'neutral/calm_female', 'happy_female', 'neutral/calm_female', 'neutral/calm_female', 'neutral/calm_female', 'happy_female', 'happy_female', 'happy_female', 'neutral/calm_female', 'happy_female', 'neutral/calm_female', 'neutral/calm_female', 'neutral/calm_female', 'happy_female', 'happy_female', 'neutral/calm_female', 'happy_female', 'happy_female', 'neutral/calm_female', 'neutral/calm_female', 'happy_female', 'happy_female', 'neutral/calm_female', 'neutral/calm_female', 'neutral/calm_female', 'happy_female', 'happy_female', 'neutral/calm_female', 'happy_female', 'happy_female', 'neutral/calm_female', 'happy_female', 'neutral/calm_female', 'neutral/calm_female', 'happy_female', 'happy_female', 'happy_female', 'neutral/calm_female', 'neutral/calm_female', 'neutral/calm_female', 'neutral/calm_female', 'happy_female', 'happy_female', 'happy_female', 'neutral/calm_female', 'happy_female', 'neutral/calm_female', 'neutral/calm_female', 'neutral/calm_female', 'happy_female', 'happy_female ...

# %% [markdown]
# # Extract Images From Videos

# %%
# Importing all necessary libraries 
import cv2 
import os 
Image="/content/drive/MyDrive/ravdess/ravdess/"
currentFrame = 0
for i in actor_folders:
    filename = os.listdir(Image + i) #iterate over Actor folders
    for file in filename: # go through files in Actor folder
       if file.endswith(".mp4"):
         path=os.path.join("/content/drive/MyDrive/ravdess/ravdess/" + i + '/', str(file))
         cam = cv2.VideoCapture(path) 
         #print(path)
         #images, frame_times = get_frames_from_video(file, STRIDE)
         #frame_capture(path)
         while(True): 
         # reading from frame 
           ret,frame = cam.read() 
           if currentFrame == 6:
             break
           else:
         # if video is still left continue creating images 
              name = '/content/drive/MyDrive/ravdess/ravdess/Images/frame' + str(currentFrame) + '.jpg'
              print ('Creating...' + name)
              cv2.imwrite(name,frame) 
           currentFrame += 1 
         # writing the extracted images 
             
         # increasing counter so that it will 
         # show how many frames are created 
             
     
  
# Release all space and windows once done 
cam.release() 
cv2.destroyAllWindows()
# Out:
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame0.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame1.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame2.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame3.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame4.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame5.jpg

# %%
# Importing all necessary libraries 
import cv2 
import os 
  
# Read the video from specified path 
cam = cv2.VideoCapture("/content/drive/MyDrive/ravdess/ravdess/Actor_21/01-01-01-01-01-01-21.mp4") 
  
try: 
      
    # creating a folder named data 
    if not os.path.exists('/content/drive/MyDrive/ravdess/ravdess/Images'): 
        os.makedirs('/content/drive/MyDrive/ravdess/ravdess/Images') 
  
# if not created then raise error 
except OSError: 
    print ('Error: Creating directory of images') 
  
# frame 
currentframe = 0
  
while(True): 
      
    # reading from frame 
    ret,frame = cam.read() 
  
    if ret: 
        # if video is still left continue creating images 
        name = '/content/drive/MyDrive/ravdess/ravdess/Images/frame' + str(currentframe) + '.jpg'
        print ('Creating...' + name) 
  
        # writing the extracted images 
        cv2.imwrite(name, frame) 
  
        # increasing counter so that it will 
        # show how many frames are created 
        currentframe += 1
    else: 
        break
  
# Release all space and windows once done 
cam.release() 
cv2.destroyAllWindows()
# Out:
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame0.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame1.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame2.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame3.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame4.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame5.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame6.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame7.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame8.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame9.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame10.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame11.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame12.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame13.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame14.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame15.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame16.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame17.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame18.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame19.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame20.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame21.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame22.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame23.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame24.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame25.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame26.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame27.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame28.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame29.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame30.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame31.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame32.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame33.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame34.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame35.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame36.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame37.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame38.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame39.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame40.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame41.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame42.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame43.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame44.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame45.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame46.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame47.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame48.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame49.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame50.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame51.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame52.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame53.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame54.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame55.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame56.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame57.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame58.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame59.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame60.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame61.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame62.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame63.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame64.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame65.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame66.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame67.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame68.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame69.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame70.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame71.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame72.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame73.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame74.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame75.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame76.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame77.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame78.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame79.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame80.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame81.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame82.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame83.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame84.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame85.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame86.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame87.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame88.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame89.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame90.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame91.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame92.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame93.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame94.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame95.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame96.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame97.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame98.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame99.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame100.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame101.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame102.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame103.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame104.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame105.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame106.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame107.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame108.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame109.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame110.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame111.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame112.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame113.jpg
# Creating.../content/drive/MyDrive/ravdess/ravdess/Images/frame114.jpg

# %%
import shutil, sys 
shutil.rmtree('/content/drive/MyDrive/ravdess/ravdess/Images/')

# %%
import cv2
import numpy as np
import os

def frame_capture(file):
  # Playing video from file:
  cap = cv2.VideoCapture(file)

  try:
      if not os.path.exists('/content/drive/MyDrive/ravdess/ravdess/Images'):
          os.makedirs('/content/drive/MyDrive/ravdess/ravdess/Images')
  except OSError:
      print('Error: Creating directory of the Image')

  currentFrame = 0
  while(True):
      # Capture frame by frame
      ret, frame = cap.read()
      # Only take the first frame and tenth frame
      if currentFrame == 6:
          name = '/content/drive/MyDrive/ravdess/ravdess/Images/frame' + str(currentFrame) + '.jpg'
          print ('Creating...' + name)
          cv2.imwrite(name, frame)

      # To stop duplicate images
      currentFrame += 1

  cap.release()
  cv2.destroyAllWindows()

# %%
try: 
      
    # creating a folder named data 
    if not os.path.exists('/content/drive/MyDrive/ravdess/ravdess/Images/faces'): 
        os.makedirs('/content/drive/MyDrive/ravdess/ravdess/Images/faces') 
  
# if not created then raise error 
except OSError: 
    print ('Error: Creating directory of images')

# %%
ImagePath= glob.glob("/content/drive/MyDrive/ravdess/ravdess/Images/*.jpg")
currentface = 0
for img in ImagePath:
          #p=path.joinpath(i)
         # print(img)
          #ret,frame = cam.read()
    image = cv2.imread(img)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
    faces = faceCascade.detectMultiScale(
        gray,
        scaleFactor=1.3,
        minNeighbors=3,
        minSize=(30, 30))
    print("Found {0} Faces!".format(len(faces)))
    for (x, y, w, h) in faces:
         i=cv2.rectangle(image, (x, y), (x+w, y+h), (0, 255, 0), 2)
         path =  '/content/drive/MyDrive/ravdess/ravdess/Images/faces/face' + str(currentface) + '.jpg'
         currentface +=1
         cv2.imwrite(path, i)
# Out:
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!
# Found 1 Faces!

# %%
try:
    # creating a folder named data 
    if not os.path.exists('/content/drive/MyDrive/ravdess/ravdess/Images/ResizedImage'): 
        os.makedirs('/content/drive/MyDrive/ravdess/ravdess/Images/ResizedImage') 
  
# if not created then raise error 
except OSError: 
    print ('Error: Creating directory of faces') 
  
path = "/content/drive/MyDrive/ravdess/ravdess/Images/faces/"
dirs = os.listdir(path)
for item in dirs:
            im = Image.open(path + item)
            f, e = os.path.splitext(path+item)
            imResize = im.resize((64,64), Image.ANTIALIAS)
            imResize.save('/content/drive/MyDrive/ravdess/ravdess/Images/ResizedImage/'+item, 'JPEG', quality=90)

# %%
import shutil, sys 
shutil.rmtree('/content/drive/MyDrive/ravdess/ravdess/Images/ResizedImage')

# %% [markdown]
# ## Split The Dataset

# %%
#Important parameters and training/Test size
prediction_time = 1 
testdatasize = 8000
unroll_length = 50
testdatacut = testdatasize + unroll_length  + 1

#Training data
x_train = data_n[0:-prediction_time-testdatacut].values
y_train = data_n[prediction_time:-testdatacut  ][0].values

#Test data
x_test = data_n[0-testdatacut:-prediction_time].values
y_test = data_n[prediction_time-testdatacut:  ][0].values

# %% [markdown]
# ## Building The LSTM Model

# %%
#Importing Required Libraries
import pandas as pd
import numpy as np
import matplotlib
import seaborn as sns
sns.set(color_codes=True)
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn
import matplotlib.dates as md
from sklearn import preprocessing
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM
from keras.models import Sequential
from keras.optimizers import Adam
import time
import datetime
from datetime import datetime

# %%
model = Sequential()

model.add(LSTM(100,input_dim=x_train.shape[-1], return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(100, return_sequences=False))
model.add(Dropout(0.2))

model.add(Dense(6))
model.add(Activation('linear'))

start = time.time()
model.compile(loss='mae', optimizer='Adam')
print('compilation time : {}'.format(time.time() - start))
model.summary()

# %%
if file.endswith('.jpg'):
            im = Image.open(file)
            f, e = os.path.splitext(file)
            imResize = im.resize((64,64), Image.ANTIALIAS)
            imResize.save(f + ' resized.jpg', 'JPEG', quality=90)
            print('done')

# %%
try:
    # creating a folder named data 
    if not os.path.exists('/content/drive/MyDrive/ravdess/ravdess/Images/faces'): 
        os.makedirs('/content/drive/MyDrive/ravdess/ravdess/Images/faces') 
  
# if not created then raise error 
except OSError: 
    print ('Error: Creating directory of faces')

# %%
status = cv2.imwrite('faces_detected.jpg', image)

# %%
print(status)
# Out:
# True

# %%
pip install tqdm
# Out:
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (4.41.1)

# %%
#!/usr/bin/python
from PIL import Image
import os, sys

#path = "/root/Desktop/python/images/"
path = "/content/"
dirs = os.listdir( path )

def resize():
    for item in dirs:
        if os.path.isfile(path+item):
            im = Image.open(path+item)
            f, e = os.path.splitext(path+item)
            imResize = im.resize((64,64), Image.ANTIALIAS)
            imResize.save(f + ' resized.jpg', 'JPEG', quality=90)

resize()

# %%
print(images)
# Out:
# []

# %%
def get_frames_from_video(video_file, stride=1.0):
    """
    video_file - path to file
    stride - i.e 1.0 - extract frame every second, 0.5 - extract every 0.5 seconds
    return: list of images, list of frame times in seconds
    """
    video = cv2.VideoCapture(video_file)
    fps = video.get(cv2.CAP_PROP_FPS)
    i = 0.
    images = []
    frame_times = []

    while video.isOpened():
        ret, frame = video.read()
        if ret:
            images.append(frame)
            frame_times.append(i)
            i += stride
            video.set(1, round(i * fps))
        else:
            video.release()
            break
    return images, frame_times


def resize_if_necessary(image, max_size=1024):
    """
    if any spatial shape of image is greater 
    than max_size, resize image such that max. spatial shape = max_size,
    otherwise return original image
    """
    if max_size is None:
        return image
    height, width = image.shape[:2]
    if max([height, width]) > max_size:
        ratio = float(max_size / max([height, width]))
        image = cv2.resize(image, (0, 0), fx=ratio, fy=ratio, interpolation=cv2.INTER_CUBIC)
    return image

# %%
STRIDE = 1.0
MAX_IMAGE_SIZE = 64
#images, frame_times = get_frames_from_video('/content/drive/MyDrive/ravdess/ravdess/Actor_21/01-01-01-01-01-01-21.mp4', STRIDE)
images = [resize_if_necessary(image, MAX_IMAGE_SIZE) for image in images]

# %%
import os
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(20,10))
columns = 5
for i, (image, frame_time) in enumerate(zip(images, frame_times)):
    plt.subplot(len(images) / columns + 1, columns, i + 1).set_title("Frame time: " + str(frame_time))
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %%
print(images)
# Out:
# []

# %% [markdown]
# # Assignment 2/C
# **Disclaimer: Only for ADL/AML students!**
#
# ### General information
# **You have to solve all tasks to pass!**
#
# Grade is calculated by the day of the last submission, but you will only get it after you've succesfully presented it.
#
# *Deadlines and grades:*
#   * 2020.10.27 - 2020.11.24 ==> 5
#   * 2020.11.25 - 2020.12.01 ==> 4
#   * 2020.12.02 - 2020.12.08 ==> 3
#   * 2020.12.09 - 2020.12.15 ==> 2
#   * 2020.12.16 or later ==> 1
#
# You can **use only these** 3rd party **packages:** `cv2, keras, matplotlib, numpy, pandas, sklearn, skimage, tensorflow, librosa`.
#
# ### Description
# In this assignment you have to build a multimodal deep neural network for emotion detection using tf.keras. You have to work with the RAVDESS dataset, which contains short (~4 seconds long) video clip recordings of speakers, who are acting the different emotions through 2 sentences. We will extract and combine RGB frames with MFCCs and utilize both video and audio information sources to achieve a better prediction.
#
# ### Use GPU
# Runtime -> Change runtime type
#
# At Hardware accelerator select  GPU then save it.
#
# ### Useful shortcuts
# * Run selected cell: *Ctrl + Enter*
# * Insert cell below: *Ctrl + M B*
# * Insert cell above: *Ctrl + M A*
# * Convert to text: *Ctrl + M M*
# * Split at cursor: *Ctrl + M -*
# * Autocomplete: *Ctrl + Space* or *Tab*
# * Move selected cells up: *Ctrl + M J*
# * Move selected cells down: *Ctrl + M K*
# * Delete selected cells: *Ctrl + M D*
#
# If you have any question, feel free to ask.
# fodorad201@gmail.com

# %% [markdown]
# ## Prepare dataset
#
# * Download the RAVDESS dataset. Here you can find more information about the dataset: https://zenodo.org/record/1188976#.X5g53OLPw2w
# The dataset is available here as well: http://nipg1.inf.elte.hu:8765
# ravdess.zip contains all of the mp4 clips. The labels are in the file names. (classification task)
#
# * Preprocess the data.
#   * Remove the silence parts from the beginning and the end of video clips. (Tips: ffmpeg filters)
#   * Audio representation:
#     * Extract the audio from the video. (Tips: ffmpeg)
#     * Extract 24 Mel Frequency Cepstral Coefficients from the audio. (Tips: use librosa.)
#     * Calculate the mean number of (spectral) frames in the dataset.
#     * Standardize the MFCCs sample-wise. (Tips: zero mean and unit variance)
#     * Use pre-padding (Note: with 0, which is also the mean after standardization) to unify the length of the samples.
#     * Audio representation per sample is a tensor with shape (N,M,1) where N is the number of coefficients (e.g. 24) and M is the number of audio frames.
#   * Visual representation:
#     * Extract the faces from the images. (Tips: You can use the cv2.CascadeClassifier, or the DLIB package to determine facial keypoints, or MTCNN to predict bounding boxes.)
#     * Resize the face images to 64x64. (Tips: You can use lower/higher resolution as well.)
#     * Subsample the frames to reduce complexity (6 frames/video is enough).
#     * Apply data augmentation, and scaling [0, 1].
#     * Video representation per sample is a tensor with shape (F,H,W,3) where F is the number of frames (e.g. 6), H and W are the spatial dimensions (e.g. 64).
#   * Ground truth labels:
#     * There are 8 class labels. However, Class 1 (Neutral) and Class 2 (Calm) are almost the same. It is a commonly used practice to merge these two classes. Combine them to reduce complexity.
#     * (Optional) Use one-hot-encoding with categorical_crossentropy loss later on, or keep them between [0, 6] and use sparse_categorical_crossentropy loss. It's up to you.
#
# * Split the datasets into train-valid-test sets. Samples from the same speaker shouldn't appear in multiple sets. (Example split using speaker ids: 1-17: train set, 18-22: validation set, 23-24: test set)
# * Create a generator, which iterates over the audio and visual representations. (Note: the generator should produce a tuple ([x0, x1], y), where x0 is the audio, x1 is the video representation, y is the ground truth.
# * Print the size of each set, plot 3 samples: frames, MFCCs and their corresponding emotion class labels. (Tips: use librosa for plotting MFCCs)
#
# Alternative considerations. They may require additional steps:
# * You can use Mean (axis=1) MFCCs vectors to further reduce complexity. Input of the corresponding subnetwork should be modified to accept inputs with shape (N, 1).
# * You can use log-melspectrograms as well. Note, that raw spectrograms are displaying power. Mel scale should be applied on the frequency axis, and log on the third dimension (decibels are expected). You can use librosa for that (librosa.feature.melspectrogram, librosa.power_to_db)
# * A better evaluation procedure here is the LOO (Leave-One-Out) cross-validation, however it can be costy.

# %%
# New model
from keras.layers.convolutional import Conv1D
from keras.models import Sequential
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, LSTM, merge
from keras.layers import BatchNormalization
import tensorflow as tf
import numpy as np
from tensorflow.keras.layers import Conv1D, MaxPooling1D, SimpleRNN, Bidirectional, Input
from tensorflow.python.keras import Model, Sequential
def fcnet(input_size=(64, 64, 3)):
 model = Sequential()
 model.add(Conv1D(32, 3),input_shape=input_size,Activation('relu'))
 model.add(BatchNormalization())
 model.add(Activation('relu'))
 model.add(Conv1D(32, 3))
 model.add(BatchNormalization())
 model.add(Activation('relu'))
 model.add(Conv1D(64, 3))
 model.add(BatchNormalization())
 model.add(Activation('relu'))
 model.add(Dropout(0.25))
 model.add(Dense(128)) # Target class number
 model.add(Activation('relu'))
 model.summary()
# Out:
#   File "<ipython-input-60-339b4fc560a5>", line 12
#     model.add(Conv1D(32, 3),input_shape=input_size,Activation('relu'))
#                                                   ^
# SyntaxError: positional argument follows keyword argument

# %%
output_length = 32 

dropout = 0.5
lstm_dim = 256

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.layers.embeddings import Embedding
from keras.layers.recurrent import LSTM
from keras.layers import Bidirectional, TimeDistributed
from keras.callbacks import EarlyStopping

def fcnet(input_size=(64, 64, 3)):
 model = Sequential()
 model.add(Bidirectional(LSTM(64), reset_selective = True))
 model.add(tf.keras.layers.Dropout(0.5))
 model.add(tf.keras.layers.Bidirectional(LSTM(64)))
 model.add(tf.keras.layers.Dense(units = 128, activation = 'relu'))
 model.add(Dense(units = 1, activation = 'softmax'))
 print(model.summary())

model = fcnet(input_size=(64, 64, 3))
model.summary()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-65d962b87014> in <module>()
#      16  print(model.summary())
#      17
# ---> 18 model = fcnet(input_size=(64, 64, 3))
#      19 model.summary()
#
# <ipython-input-66-65d962b87014> in fcnet(input_size)
#       9 def fcnet(input_size=(64, 64, 3)):
#      10  model = Sequential()
# ---> 11  model.add(Bidirectional(LSTM(64), reset_selective = True))
#      12  model.add(tf.keras.layers.Dropout(0.5))
#      13  model.add(tf.keras.layers.Bidirectional(LSTM(64)))
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/layers/wrappers.py in __init__(self, layer, merge_mode, weights, backward_layer, **kwargs)
#     420     # of it we actually run.
#     421     self._setattr_tracking = False
# --> 422     super(Bidirectional, self).__init__(layer, **kwargs)
#     423     self._setattr_tracking = True
#     424
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/layers/wrappers.py in __init__(self, layer, **kwargs)
#      53     assert isinstance(layer, Layer)
#      54     self.layer = layer
# ---> 55     super(Wrapper, self).__init__(**kwargs)
#      56
#      57   def build(self, input_shape=None):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/base.py in _method_wrapper(self, *args, **kwargs)
#     515     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     516     try:
# --> 517       result = method(self, *args, **kwargs)
#     518     finally:
#     519       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/base_layer.py in __init__(self, trainable, name, dtype, dynamic, **kwargs)
#     338     }
#     339     # Validate optional keyword arguments.
# --> 340     generic_utils.validate_kwargs(kwargs, allowed_kwargs)
#     341
#     342     # Mutable properties
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/utils/generic_utils.py in validate_kwargs(kwargs, allowed_kwargs, error_message)
#     806   for kwarg in kwargs:
#     807     if kwarg not in allowed_kwargs:
# --> 808       raise TypeError(error_message, kwarg)
#     809
#     810
#
# TypeError: ('Keyword argument not understood:', 'reset_selective')

# %%
token_num = 4000 
data_length =100
model = Sequential()
model.add(Embedding(output_dim = output_length, 
                    input_dim = token_num, 
                    input_length = data_length))
model.add(Dropout(dropout))

# using BLSTM (this will be better than LSTM, Avg acc is around 0.85
model.add(Bidirectional(LSTM(lstm_dim), merge_mode = 'sum'))
model.add(Dropout(dropout))


model.add(Dense(units = 256, activation = 'relu'))
model.add(Dropout(dropout))

model.add(Dense(units = 1, activation = 'sigmoid'))
print(model.summary())
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 100, 32)           128000
# _________________________________________________________________
# dropout (Dropout)            (None, 100, 32)           0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 256)               591872
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 256)               65792
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 785,921
# Trainable params: 785,921
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ## Create Model
#
# * Create the audio subnetwork
#   * Choose one of these:
#     * BLSTM (64 units, return sequences) + Dropout 0.5 + BLSTM (64 units) + Dense (128 units, ReLU)
#     * Conv1D (32 filters, 3x3) + BatchNorm + ReLU, Conv1D (32 filters, 3x3) + BatchNorm + ReLU, Conv1D (64 filters, 3x3) + BatchNorm + ReLU, LSTM (64 units) + Dropout 0.5 + Dense (128 units, ReLU)
#     * Conv2D (32 filters, 3x3) + BatchNorm + ReLU, MaxPool2D, Conv2D (32 filters, 3x3) + BatchNorm + ReLU, MaxPool2D, Flatten, Dense (128 units, ReLU)
#   * You can try other configurations, better submodels. Have a reason for your choice!
# * Create the visual subnetwork
#   * Choose a visual backbone, which is applied frame-wise (Tips: use TimeDistributed Layer for this):
#     * VGG-like architecture (Conv2D + MaxPooling blocks)
#     * ResNet / Inception architecture (Residual blocks, Inception cells)
#   * You can try other configurations, better submodels (like 3D convolution nets). Have a reason for your choice!
#   * Apply Max pooling over the time dimension to reduce complexity (or use GRU or LSTM for better temporal modelling)
# * Model fusion:
#   * Concatenate the final hidden representations of the audio and visual subnetwork.
#   * Apply fully connected layers on it (256 units, ReLU), then an another dense layer (7 units, softmax).
#   * You can feed multiple inputs to the Model using a list:
#   model = tf.keras.models.Model(inputs=[input_audio, input_video], outputs=output)
#
# ## Extra task (Optional)
# Use the VGGFace2 model (and pretrained weights) in the visual subnetwork. It is trained on faces, so a much better representation can be obtained with it. Finetune the network for enhanced prediction.
# (code: https://github.com/rcmalli/keras-vggface, but other implementation can be used as well)
# Note, that this repository use the classic keras, while we are using tf.keras.
# It may rise compatibility problems.
#
# **If you can successfully use the VGGFace2 pretrained net, +1 is added to the final grade.**

# %% [markdown]
# ## Additional notes
#
# * Do the preprocessing steps offline, create pkl (or npy, hdf5, etc..) files, so you don't have to repeat most of the steps again. Then you can upload it, and train using colab without much struggling.
# * Use Adam optimizer.
# * Use learning rate scheduler.
# * Check the training curve. If overfitting happens, add more regularization: weight decay (L2: 1e-3, 5e-4, etc...), Dropout
#
# ## Final steps, evaluation
#
# * Plot the training / validation curve.
# * Calculate accuracy, print a confusion matrix.
